# %% [markdown]
# # course-file-tree-generator
#
#
# + Falta: Ordenar videos, por numeraçao deles e ordenar essa enumeraçao depois, pois seano fica 1, 10,22 ... 2, 20 21 , .... => isso pode ser feito passando com `.zfill(2)`
# + Separar em nome competo, nome sem numero, e numero
#
# + Mesmo que aqui a codificaço fique bugada, na saida no arquivo nao fica

# %%
import os
import json

# %%
import moviepy.editor

# %%
 # windows :: \\, linux: /
separator = '/'

# %% [markdown]
# ## Snippets

# %%
# Converts into more readable format 
def convert(seconds):
    hours = seconds // 3600
    seconds %= 3600
    mins = seconds // 60
    seconds %= 60
    return hours, mins, seconds

# format: 00h00m00s
def get_convert(hours, mins, secs):
    if(hours == 0):
        return str(mins).zfill(2) + 'm' + str(secs).zfill(2) + 's'
    else:
        return str(hours).zfill(2) + 'h' + str(mins).zfill(2) + 'm' + str(secs).zfill(2) + 's'

# get duraction of video-file
def get_duraction_of_file(filepath):
    video_duration = 6000
#     video = moviepy.editor.VideoFileClip(filepath)
#     video_duration = int(video.duration)
    hours, mins, secs = convert(video_duration)
    return get_convert(hours, mins, secs), video_duration

# %%
def list_files(dir):
    r = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            r.append(os.path.join(root, name))
    return r

# %% [markdown]
# ## Get Root

# %%
# Out:
# '/media/rhavel/7A60E25D60E21F9D/-1HeavyHD/Big Courses/Curso Sites Lucrativos [ WordPress, ElementorPro ]'

# %%
root_course = os.getcwd().split(separator)[-1]
root_course
# Out:
# 'Curso Sites Lucrativos [ WordPress, ElementorPro ]'

# %% [markdown]
# ## Get Folders

# %%
# Get all sub-folders of actual directory
path = '.'
all_directory_files_contents = os.listdir(path)

# Filter Directories Only
all_dirs = list(filter(lambda x: os.path.isdir(x), all_directory_files_contents))
all_dirs

# Remove folders invalids
list_of_exlcude_dirs = ['.ipynb_checkpoints']

for el in list_of_exlcude_dirs:
    if(el in all_dirs):
        all_dirs.remove(el)
        
# Show result
all_dirs
# Out:
# ['14 - Negociação',
#  '01 - Introdução (LEIA ANTES DE COMEÇAR)',
#  '02 - Pré Requisito',
#  '03 - Planejamento do Site',
#  '04 - Manipulação de Imagens',
#  '05 - Criando uma Landing Page',
#  '06 - Criando um Site Institucional (PARTE 1)',
#  '07 - Site Institucional (PARTE 2)',
#  '08 - Criando Um Blog',
#  '09 - Fazendo Uma Loja Virtual',
#  '10 - Criando Uma Loja Virtual (Antigo)',
#  '11 - Plugins e Ferramentas Essenciais',
#  '12 - Email Marketing',
#  '13 - S.E.O. (Otimização para o Google)',
#  '15 - Extras',
#  '16 - AULÕES DE SEXTA',
#  '17 - Elementor Pro',
#  '18 - Reuniões com Clientes (Estudos de Caso)',
#  '19 - Desenvolvendo um Site de Cliente - Passo a passo completo',
#  '20 - Análises de Sites de Alunos',
#  '21 - MENTORIAS EM GRUPO',
#  '22 - MOBILE FIRST',
#  '23 - Trabalhando de Forma Remota',
#  '24 - Site Anitta - (Efeitos de Movimento e PopUp)',
#  '25 - Teoria das Cores',
#  '26 - Como Criar um Logotipo Simples',
#  '27 - Maratona Lucrando com Sites']

# %% [markdown]
# ## Sort Folders: Dict Structure
#
# Infelizmente, vai ler na ordem, 1 => 10 => 11 ... , 2 => 20 => 21 ,... ,  e nao queremos isso. ENtâ vamos criar uma lsita de tuplas, onde cada tulpla te tamanho 3 e segue a ordem:
#
# ````
# (numero, nome-completo, nome-sem-enumeracao)
# ````
#
# **OBS:** Deverá ser alterado apra cada estrutura de pasta

# %%
def get_number_of_folder(dir_name):
    # Essa regra vai variar para cada curso
    return str(dir_name.split('-')[0]).zfill(2)

# %%
maping_sorted_dict = {}
for el in all_dirs:
    maping_sorted_dict[int(get_number_of_folder(el))] = (el, el.split('-')[1].strip()) # nome , nome se numero

maping_sorted_dict = sorted(maping_sorted_dict.items(), key=lambda x: x[0])
maping_sorted_dict
# Out:
# [(1,
#   ('01 - Introdução (LEIA ANTES DE COMEÇAR)',
#    'Introdução (LEIA ANTES DE COMEÇAR)')),
#  (2, ('02 - Pré Requisito', 'Pré Requisito')),
#  (3, ('03 - Planejamento do Site', 'Planejamento do Site')),
#  (4, ('04 - Manipulação de Imagens', 'Manipulação de Imagens')),
#  (5, ('05 - Criando uma Landing Page', 'Criando uma Landing Page')),
#  (6,
#   ('06 - Criando um Site Institucional (PARTE 1)',
#    'Criando um Site Institucional (PARTE 1)')),
#  (7, ('07 - Site Institucional (PARTE 2)', 'Site Institucional (PARTE 2)')),
#  (8, ('08 - Criando Um Blog', 'Criando Um Blog')),
#  (9, ('09 - Fazendo Uma Loja Virtual', 'Fazendo Uma Loja Virtual')),
#  (10,
#   ('10 - Criando Uma Loja Virtual (Antigo)',
#    'Criando Uma Loja Virtual (Antigo)')),
#  (11,
#   ('11 - Plugins e Ferramentas Essenciais',
#    'Plugins e Ferramentas Essenciais')),
#  (12, ('12 - Email Marketing', 'Email Marketing')),
#  (13,
#   ('13 - S.E.O. (Otimização para o Google)',
#    'S.E.O. (Otimização para o Google)')),
#  (14, ('14 - Negociação', 'Negociação')),
#  (15, ('15 - Extras', 'Extras')),
#  (16, ('16 - AULÕES DE SEXTA', 'AULÕES DE SEXTA')),
#  (17, ('17 - Elementor Pro', 'Elementor Pro')),
#  (18,
#   ('18 - Reuniões com Clientes (Estudos de Caso)',
#    'Reuniões com Clientes (Estudos de Caso)')),
#  (19,
#   ('19 - Desenvolvendo um Site de Cliente - Passo a passo completo',
#    'Desenvolvendo um Site de Cliente')),
#  (20, ('20 - Análises de Sites de Alunos', 'Análises de Sites de Alunos')),
#  (21, ('21 - MENTORIAS EM GRUPO', 'MENTORIAS EM GRUPO')),
#  (22, ('22 - MOBILE FIRST', 'MOBILE FIRST')),
#  (23, ('23 - Trabalhando de Forma Remota', 'Trabalhando de Forma Remota')),
#  (24, ('24 - Site Anitta - (Efeitos de Movimento e PopUp)', 'Site Anitta')),
#  (25, ('25 - Teoria das Cores', 'Teoria das Cores')),
#  (26,
#   ('26 - Como Criar um Logotipo Simples', 'Como Criar um Logotipo Simples')),
#  (27, ('27 - Maratona Lucrando com Sites', 'Maratona Lucrando com Sites'))]

# %% [markdown]
# ## Execute Processe - Generate Folders Structure
#
# Devo iterarra e criar uma super esttutura de ados que tera´todos os dados, e no final, eu faço o write nos arquivos, tanto no Readme quanto no repsctivo course/01-module.md
#
# curso total = tempo x
#
# ````
# {
#     name_course: root,
#     time_course: 00:00:00,
#     time_course_seconds: 0,
#     number_of_modules: 0,
#     modules: [
#         {
#             name: 'module-01-xxx',
#             number: '1',
#             time_module: 00:00:00,
#             time_module_seconds: 0,
#             number_of_videos: 0,
#             files: [
#                 {
#                     name: 'file-01'
#                     time_video: 00:00:00,
#                 },
#                 ...
#             ],
#         },
#         ...
#     ],
# }
# ````json

# %%
# Recuperando todas as pastas do curso
folders_sorted_of_course = maping_sorted_dict
folders_sorted_of_course
# Out:
# [(1,
#   ('01 - Introdução (LEIA ANTES DE COMEÇAR)',
#    'Introdução (LEIA ANTES DE COMEÇAR)')),
#  (2, ('02 - Pré Requisito', 'Pré Requisito')),
#  (3, ('03 - Planejamento do Site', 'Planejamento do Site')),
#  (4, ('04 - Manipulação de Imagens', 'Manipulação de Imagens')),
#  (5, ('05 - Criando uma Landing Page', 'Criando uma Landing Page')),
#  (6,
#   ('06 - Criando um Site Institucional (PARTE 1)',
#    'Criando um Site Institucional (PARTE 1)')),
#  (7, ('07 - Site Institucional (PARTE 2)', 'Site Institucional (PARTE 2)')),
#  (8, ('08 - Criando Um Blog', 'Criando Um Blog')),
#  (9, ('09 - Fazendo Uma Loja Virtual', 'Fazendo Uma Loja Virtual')),
#  (10,
#   ('10 - Criando Uma Loja Virtual (Antigo)',
#    'Criando Uma Loja Virtual (Antigo)')),
#  (11,
#   ('11 - Plugins e Ferramentas Essenciais',
#    'Plugins e Ferramentas Essenciais')),
#  (12, ('12 - Email Marketing', 'Email Marketing')),
#  (13,
#   ('13 - S.E.O. (Otimização para o Google)',
#    'S.E.O. (Otimização para o Google)')),
#  (14, ('14 - Negociação', 'Negociação')),
#  (15, ('15 - Extras', 'Extras')),
#  (16, ('16 - AULÕES DE SEXTA', 'AULÕES DE SEXTA')),
#  (17, ('17 - Elementor Pro', 'Elementor Pro')),
#  (18,
#   ('18 - Reuniões com Clientes (Estudos de Caso)',
#    'Reuniões com Clientes (Estudos de Caso)')),
#  (19,
#   ('19 - Desenvolvendo um Site de Cliente - Passo a passo completo',
#    'Desenvolvendo um Site de Cliente')),
#  (20, ('20 - Análises de Sites de Alunos', 'Análises de Sites de Alunos')),
#  (21, ('21 - MENTORIAS EM GRUPO', 'MENTORIAS EM GRUPO')),
#  (22, ('22 - MOBILE FIRST', 'MOBILE FIRST')),
#  (23, ('23 - Trabalhando de Forma Remota', 'Trabalhando de Forma Remota')),
#  (24, ('24 - Site Anitta - (Efeitos de Movimento e PopUp)', 'Site Anitta')),
#  (25, ('25 - Teoria das Cores', 'Teoria das Cores')),
#  (26,
#   ('26 - Como Criar um Logotipo Simples', 'Como Criar um Logotipo Simples')),
#  (27, ('27 - Maratona Lucrando com Sites', 'Maratona Lucrando com Sites'))]

# %%
# Inicializar estrutura do curso inteiro
course_tree = {
    'name_course': root_course,
    'time_course': '',
    'time_course_seconds': 0,
    'number_of_modules': 0,
    'modules' : [],
}

# Files to filter
filter_videos_files = ['mp4','ts']

# Iterar sobre as pastas do curso
# filepath_module com numero, sem numero
for number_of_module, filepath_module in folders_sorted_of_course:
    
    filepath_name, numberless_name = filepath_module[0], filepath_module[1]
    print('\n====================', number_of_module, numberless_name, '\n')
    
    # initialize module tree
    module_tree = {
        'name': filepath_name,
        'number': number_of_module,
        'finalize_name': str(number_of_module).zfill(2) + ' - ' + numberless_name,
        'time_module': '',
        'time_module_seconds': 0,
        'number_of_videos': 0,
        'files': [],
    }
    print('-----------',  str(number_of_module).zfill(2) + ' - ' + numberless_name)
    
    # Get and  Analyse videos
    video_files = list(filter(lambda x: x.split('.')[-1] in filter_videos_files, list_files(filepath_name)))
    for el in video_files:
        video_name = (os.path.splitext(el)[0]).split(separator)[-1]
        print(video_name)
        video_tree = {
            'name': '',
            'time_video': '',
            'time_video_seconds': '',
        }
        time_string, video_seconds = get_duraction_of_file(el)
        # save video data
        video_tree['time_video_seconds'] = video_seconds
        video_tree['time_video'] = time_string
        video_tree['name'] = video_name
        print('video_tree ::', video_tree, '\n')
        # save in module data
        module_tree['files'].append(video_tree)
        module_tree['number_of_videos'] += 1
        module_tree['time_module_seconds'] += video_seconds

    h, m, s = convert(module_tree['time_module_seconds'])
    module_tree['time_module'] = get_convert(h, m, s)
    
    # END
    print('\n => module_tree ::')
    print(json.dumps(module_tree, indent=4))
    course_tree['modules'].append(module_tree)
# Out:
# ==================== 1 Introdução (LEIA ANTES DE COMEÇAR)
#
# ----------- 01 - Introdução (LEIA ANTES DE COMEÇAR)
# 01 - Bem Vindo
# video_tree :: {'name': '01 - Bem Vindo', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Bônus Elementor Pro
# video_tree :: {'name': '03 - Bônus Elementor Pro', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Estrutura do Curso
# video_tree :: {'name': '05 - Estrutura do Curso', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "01 - Introdu\u00e7\u00e3o (LEIA ANTES DE COME\u00c7AR)",
#     "number": 1,
#     "finalize_name": "01 - Introdu\u00e7\u00e3o (LEIA ANTES DE COME\u00c7AR)",
#     "time_module": "05h00m00s",
#     "time_module_seconds": 18000,
#     "number_of_videos": 3,
#     "files": [
#         {
#             "name": "01 - Bem Vindo",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - B\u00f4nus Elementor Pro",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Estrutura do Curso",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 2 Pré Requisito
#
# ----------- 02 - Pré Requisito
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - O que é e como escolher um Domínio
# video_tree :: {'name': '02 - O que é e como escolher um Domínio', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Como contratar Hospedagem
# video_tree :: {'name': '03 - Como contratar Hospedagem', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Como Instalar o WordPress
# video_tree :: {'name': '04 - Como Instalar o WordPress', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Instalando o Elementor
# video_tree :: {'name': '05 - Instalando o Elementor', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Instalando o Elementor Pro (Maneira Oficial)
# video_tree :: {'name': '06 - Instalando o Elementor Pro (Maneira Oficial)', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Primeiros Passos com o Elementor
# video_tree :: {'name': '07 - Primeiros Passos com o Elementor', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Principais Elementos (Widgets) do Elementor
# video_tree :: {'name': '08 - Principais Elementos (Widgets) do Elementor', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Copiar e Colar e Colar Estilo (Dica)
# video_tree :: {'name': '09 - Copiar e Colar e Colar Estilo (Dica)', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Elementor - Navigator (Dica)
# video_tree :: {'name': '10 - Elementor - Navigator (Dica)', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 11 - Conclusão
# video_tree :: {'name': '11 - Conclusão', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "02 - Pr\u00e9 Requisito",
#     "number": 2,
#     "finalize_name": "02 - Pr\u00e9 Requisito",
#     "time_module": "18h20m00s",
#     "time_module_seconds": 66000,
#     "number_of_videos": 11,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - O que \u00e9 e como escolher um Dom\u00ednio",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Como contratar Hospedagem",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Como Instalar o WordPress",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Instalando o Elementor",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Instalando o Elementor Pro (Maneira Oficial)",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Primeiros Passos com o Elementor",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Principais Elementos (Widgets) do Elementor",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Copiar e Colar e Colar Estilo (Dica)",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - Elementor - Navigator (Dica)",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - Conclus\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 3 Planejamento do Site
#
# ----------- 03 - Planejamento do Site
# 01 - Qual o Propósito do seu Site (Tipos de Site)
# video_tree :: {'name': '01 - Qual o Propósito do seu Site (Tipos de Site)', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Definindo as Páginas - parte 1
# video_tree :: {'name': '02 - Definindo as Páginas - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Definindo as Páginas - parte 2
# video_tree :: {'name': '02 - Definindo as Páginas - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Criando Links
# video_tree :: {'name': '03 - Criando Links', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Planejamento de uma Página
# video_tree :: {'name': '04 - Planejamento de uma Página', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Referências
# video_tree :: {'name': '05 - Referências', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Brainstorm de uma Página
# video_tree :: {'name': '06 - Brainstorm de uma Página', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Dica para visualizar melhor um layout de página
# video_tree :: {'name': '07 - Dica para visualizar melhor um layout de página', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Buscando Referências na Prática
# video_tree :: {'name': '08 - Buscando Referências na Prática', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Principais Erros de Design
# video_tree :: {'name': '09 - Principais Erros de Design', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Bônus - Templates Exclusivos
# video_tree :: {'name': '10 - Bônus - Templates Exclusivos', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "03 - Planejamento do Site",
#     "number": 3,
#     "finalize_name": "03 - Planejamento do Site",
#     "time_module": "18h20m00s",
#     "time_module_seconds": 66000,
#     "number_of_videos": 11,
#     "files": [
#         {
#             "name": "01 - Qual o Prop\u00f3sito do seu Site (Tipos de Site)",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Definindo as P\u00e1ginas - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Definindo as P\u00e1ginas - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Criando Links",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Planejamento de uma P\u00e1gina",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Refer\u00eancias",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Brainstorm de uma P\u00e1gina",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Dica para visualizar melhor um layout de p\u00e1gina",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Buscando Refer\u00eancias na Pr\u00e1tica",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Principais Erros de Design",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - B\u00f4nus - Templates Exclusivos",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 4 Manipulação de Imagens
#
# ----------- 04 - Manipulação de Imagens
# 01 - Introdução Manipulação de Imagens
# video_tree :: {'name': '01 - Introdução Manipulação de Imagens', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Tamanhos e Resoluções
# video_tree :: {'name': '02 - Tamanhos e Resoluções', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Como ver a Resolução da Imagem
# video_tree :: {'name': '03 - Como ver a Resolução da Imagem', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Formatos de Imagens para Web
# video_tree :: {'name': '04 - Formatos de Imagens para Web', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Como ver o Formato de uma Imagem
# video_tree :: {'name': '05 - Como ver o Formato de uma Imagem', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Bancos de Imagens
# video_tree :: {'name': '06 - Bancos de Imagens', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Photoshop e Photopea
# video_tree :: {'name': '07 - Photoshop e Photopea', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Primeiras Impressões Photopea
# video_tree :: {'name': '08 - Primeiras Impressões Photopea', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Optimizadores de Imagem
# video_tree :: {'name': '09 - Optimizadores de Imagem', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Como Remover o Fundo de Uma Imagem com a varinha mágica
# video_tree :: {'name': '10 - Como Remover o Fundo de Uma Imagem com a varinha mágica', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Como Remover o Fundo de Uma Imagem
# video_tree :: {'name': '10 - Como Remover o Fundo de Uma Imagem', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 11 - Como Cortar uma Imagem
# video_tree :: {'name': '11 - Como Cortar uma Imagem', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "04 - Manipula\u00e7\u00e3o de Imagens",
#     "number": 4,
#     "finalize_name": "04 - Manipula\u00e7\u00e3o de Imagens",
#     "time_module": "20h00m00s",
#     "time_module_seconds": 72000,
#     "number_of_videos": 12,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o Manipula\u00e7\u00e3o de Imagens",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Tamanhos e Resolu\u00e7\u00f5es",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Como ver a Resolu\u00e7\u00e3o da Imagem",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Formatos de Imagens para Web",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Como ver o Formato de uma Imagem",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Bancos de Imagens",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Photoshop e Photopea",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Primeiras Impress\u00f5es Photopea",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Optimizadores de Imagem",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - Como Remover o Fundo de Uma Imagem com a varinha m\u00e1gica",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - Como Remover o Fundo de Uma Imagem",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - Como Cortar uma Imagem",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 5 Criando uma Landing Page
#
# ----------- 05 - Criando uma Landing Page
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Configurações Iniciais
# video_tree :: {'name': '02 - Configurações Iniciais', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Capa - parte 1
# video_tree :: {'name': '03 - Capa - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Capa - parte 2
# video_tree :: {'name': '03 - Capa - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Seção de Informações
# video_tree :: {'name': '04 - Seção de Informações', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Seção de Testemunhos
# video_tree :: {'name': '05 - Seção de Testemunhos', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Seção de Dados
# video_tree :: {'name': '06 - Seção de Dados', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Footer
# video_tree :: {'name': '07 - Footer', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Otimizações para Celular
# video_tree :: {'name': '08 - Otimizações para Celular', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Exportando a Página para Outros Projetos
# video_tree :: {'name': '09 - Exportando a Página para Outros Projetos', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Print da Página (Dica Extra)
# video_tree :: {'name': '10 - Print da Página (Dica Extra)', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "05 - Criando uma Landing Page",
#     "number": 5,
#     "finalize_name": "05 - Criando uma Landing Page",
#     "time_module": "18h20m00s",
#     "time_module_seconds": 66000,
#     "number_of_videos": 11,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Configura\u00e7\u00f5es Iniciais",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Capa - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Capa - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Se\u00e7\u00e3o de Informa\u00e7\u00f5es",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Se\u00e7\u00e3o de Testemunhos",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Se\u00e7\u00e3o de Dados",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Footer",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Otimiza\u00e7\u00f5es para Celular",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Exportando a P\u00e1gina para Outros Projetos",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - Print da P\u00e1gina (Dica Extra)",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 6 Criando um Site Institucional (PARTE 1)
#
# ----------- 06 - Criando um Site Institucional (PARTE 1)
# 10 - Editando as Páginas com o Elementor (Imagens) - parte 1
# video_tree :: {'name': '10 - Editando as Páginas com o Elementor (Imagens) - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - PARTE 1 - Modelos Prontos -----
# video_tree :: {'name': '02 - PARTE 1 - Modelos Prontos -----', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Configurações iniciais Necessárias
# video_tree :: {'name': '03 - Configurações iniciais Necessárias', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Instalando o Astra e Escolhendo um Modelo
# video_tree :: {'name': '04 - Instalando o Astra e Escolhendo um Modelo', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - O que mudou após a importação do modelo - parte 1
# video_tree :: {'name': '05 - O que mudou após a importação do modelo - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - O que mudou após a importação do modelo - parte 2
# video_tree :: {'name': '05 - O que mudou após a importação do modelo - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Editando a Página
# video_tree :: {'name': '06 - Editando a Página', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Editando o Tema
# video_tree :: {'name': '07 - Editando o Tema', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Editando o Menu
# video_tree :: {'name': '08 - Editando o Menu', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Editando as Páginas com o Elementor (Cores)
# video_tree :: {'name': '09 - Editando as Páginas com o Elementor (Cores)', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Editando as Páginas com o Elementor (Imagens) - parte 2
# video_tree :: {'name': '10 - Editando as Páginas com o Elementor (Imagens) - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 11 - Editando as Páginas com o Elementor (Textos)
# video_tree :: {'name': '11 - Editando as Páginas com o Elementor (Textos)', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 12 - Adicionando Novas Seções
# video_tree :: {'name': '12 - Adicionando Novas Seções', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 13 - Otimizações para Celular
# video_tree :: {'name': '13 - Otimizações para Celular', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 14 - Padronizando as Páginas - parte 1
# video_tree :: {'name': '14 - Padronizando as Páginas - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 14 - Padronizando as Páginas - parte 2
# video_tree :: {'name': '14 - Padronizando as Páginas - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 15 - Footer, Global Widget e Seções Globais - parte 1
# video_tree :: {'name': '15 - Footer, Global Widget e Seções Globais - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 15 - Footer, Global Widget e Seções Globais - parte 2
# video_tree :: {'name': '15 - Footer, Global Widget e Seções Globais - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 15 - Footer, Global Widget e Seções Globais - parte 3
# video_tree :: {'name': '15 - Footer, Global Widget e Seções Globais - parte 3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 16 - Adicionando o Feed do Instagram e Outros Plugins - parte 1
# video_tree :: {'name': '16 - Adicionando o Feed do Instagram e Outros Plugins - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 16 - Adicionando o Feed do Instagram e Outros Plugins - parte 2
# video_tree :: {'name': '16 - Adicionando o Feed do Instagram e Outros Plugins - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 17 - Conclusão Parte 1
# video_tree :: {'name': '17 - Conclusão Parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "06 - Criando um Site Institucional (PARTE 1)",
#     "number": 6,
#     "finalize_name": "06 - Criando um Site Institucional (PARTE 1)",
#     "time_module": "38h20m00s",
#     "time_module_seconds": 138000,
#     "number_of_videos": 23,
#     "files": [
#         {
#             "name": "10 - Editando as P\u00e1ginas com o Elementor (Imagens) - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - PARTE 1 - Modelos Prontos -----",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Configura\u00e7\u00f5es iniciais Necess\u00e1rias",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Instalando o Astra e Escolhendo um Modelo",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - O que mudou ap\u00f3s a importa\u00e7\u00e3o do modelo - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - O que mudou ap\u00f3s a importa\u00e7\u00e3o do modelo - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Editando a P\u00e1gina",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Editando o Tema",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Editando o Menu",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Editando as P\u00e1ginas com o Elementor (Cores)",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - Editando as P\u00e1ginas com o Elementor (Imagens) - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - Editando as P\u00e1ginas com o Elementor (Textos)",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "12 - Adicionando Novas Se\u00e7\u00f5es",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "13 - Otimiza\u00e7\u00f5es para Celular",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "14 - Padronizando as P\u00e1ginas - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "14 - Padronizando as P\u00e1ginas - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "15 - Footer, Global Widget e Se\u00e7\u00f5es Globais - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "15 - Footer, Global Widget e Se\u00e7\u00f5es Globais - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "15 - Footer, Global Widget e Se\u00e7\u00f5es Globais - parte 3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "16 - Adicionando o Feed do Instagram e Outros Plugins - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "16 - Adicionando o Feed do Instagram e Outros Plugins - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "17 - Conclus\u00e3o Parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 7 Site Institucional (PARTE 2)
#
# ----------- 07 - Site Institucional (PARTE 2)
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Referência e Planejamento - parte 1
# video_tree :: {'name': '02 - Referência e Planejamento - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Referência e Planejamento - parte 2
# video_tree :: {'name': '02 - Referência e Planejamento - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Configurações Importantes
# video_tree :: {'name': '03 - Configurações Importantes', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Página Inicial (Menu, Capa e Serviços) - parte 1
# video_tree :: {'name': '04 - Página Inicial (Menu, Capa e Serviços) - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Página Inicial (Menu, Capa e Serviços) - parte 2
# video_tree :: {'name': '04 - Página Inicial (Menu, Capa e Serviços) - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Página Inicial (Menu, Capa e Serviços) - parte 3
# video_tree :: {'name': '04 - Página Inicial (Menu, Capa e Serviços) - parte 3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Página Inicial (CTA, Descrição e Clientes) - parte 1
# video_tree :: {'name': '05 - Página Inicial (CTA, Descrição e Clientes) - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Página Inicial (CTA, Descrição e Clientes) - parte 2
# video_tree :: {'name': '05 - Página Inicial (CTA, Descrição e Clientes) - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Página Inicial (CTA, Descrição e Clientes) - parte 3
# video_tree :: {'name': '05 - Página Inicial (CTA, Descrição e Clientes) - parte 3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Página Inicial (CTA, Formulário e Footer) - parte 1
# video_tree :: {'name': '06 - Página Inicial (CTA, Formulário e Footer) - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Página Inicial (CTA, Formulário e Footer) - parte 2
# video_tree :: {'name': '06 - Página Inicial (CTA, Formulário e Footer) - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Página Inicial (CTA, Formulário e Footer) - parte 3
# video_tree :: {'name': '06 - Página Inicial (CTA, Formulário e Footer) - parte 3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Otimizando para Celular
# video_tree :: {'name': '07 - Otimizando para Celular', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Animações e Efeitos de Movimento
# video_tree :: {'name': '08 - Animações e Efeitos de Movimento', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Padronizando Menu e Footer
# video_tree :: {'name': '09 - Padronizando Menu e Footer', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Página de Contato - parte 1
# video_tree :: {'name': '10 - Página de Contato - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Página de Contato - parte 2
# video_tree :: {'name': '10 - Página de Contato - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Página de Contato - parte 3
# video_tree :: {'name': '10 - Página de Contato - parte 3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 11 - Página Sobre Nós
# video_tree :: {'name': '11 - Página Sobre Nós', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 12 - Definindo a página inicial e finalização
# video_tree :: {'name': '12 - Definindo a página inicial e finalização', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "07 - Site Institucional (PARTE 2)",
#     "number": 7,
#     "finalize_name": "07 - Site Institucional (PARTE 2)",
#     "time_module": "35h00m00s",
#     "time_module_seconds": 126000,
#     "number_of_videos": 21,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Refer\u00eancia e Planejamento - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Refer\u00eancia e Planejamento - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Configura\u00e7\u00f5es Importantes",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - P\u00e1gina Inicial (Menu, Capa e Servi\u00e7os) - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - P\u00e1gina Inicial (Menu, Capa e Servi\u00e7os) - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - P\u00e1gina Inicial (Menu, Capa e Servi\u00e7os) - parte 3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - P\u00e1gina Inicial (CTA, Descri\u00e7\u00e3o e Clientes) - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - P\u00e1gina Inicial (CTA, Descri\u00e7\u00e3o e Clientes) - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - P\u00e1gina Inicial (CTA, Descri\u00e7\u00e3o e Clientes) - parte 3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - P\u00e1gina Inicial (CTA, Formul\u00e1rio e Footer) - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - P\u00e1gina Inicial (CTA, Formul\u00e1rio e Footer) - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - P\u00e1gina Inicial (CTA, Formul\u00e1rio e Footer) - parte 3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Otimizando para Celular",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Anima\u00e7\u00f5es e Efeitos de Movimento",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Padronizando Menu e Footer",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - P\u00e1gina de Contato - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - P\u00e1gina de Contato - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - P\u00e1gina de Contato - parte 3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - P\u00e1gina Sobre N\u00f3s",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "12 - Definindo a p\u00e1gina inicial e finaliza\u00e7\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 8 Criando Um Blog
#
# ----------- 08 - Criando Um Blog
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Pra que serve um Blog
# video_tree :: {'name': '02 - Pra que serve um Blog', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Buscando Referências
# video_tree :: {'name': '03 - Buscando Referências', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Criando Seu Primeiro Post
# video_tree :: {'name': '04 - Criando Seu Primeiro Post', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Estruturas de Blog no WordPress
# video_tree :: {'name': '05 - Estruturas de Blog no WordPress', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Criando o Modelo da Página de Posts - parte 1
# video_tree :: {'name': '06 - Criando o Modelo da Página de Posts - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Criando o Modelo da Página de Posts - parte 2
# video_tree :: {'name': '06 - Criando o Modelo da Página de Posts - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Criando o Modelo da Página de Posts - parte 3
# video_tree :: {'name': '06 - Criando o Modelo da Página de Posts - parte 3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Escrevendo Boas Postagens
# video_tree :: {'name': '07 - Escrevendo Boas Postagens', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Categorias
# video_tree :: {'name': '08 - Categorias', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Criando a Página Blog
# video_tree :: {'name': '09 - Criando a Página Blog', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Usando o Widget de Posts - parte 1
# video_tree :: {'name': '10 - Usando o Widget de Posts - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Usando o Widget de Posts - parte 2
# video_tree :: {'name': '10 - Usando o Widget de Posts - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 11 - Finalizando o Layout da Página de Posts
# video_tree :: {'name': '11 - Finalizando o Layout da Página de Posts', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 12 - (Extra) Como trocar a foto de perfil do Usuário - Gravatar
# video_tree :: {'name': '12 - (Extra) Como trocar a foto de perfil do Usuário - Gravatar', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "08 - Criando Um Blog",
#     "number": 8,
#     "finalize_name": "08 - Criando Um Blog",
#     "time_module": "25h00m00s",
#     "time_module_seconds": 90000,
#     "number_of_videos": 15,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Pra que serve um Blog",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Buscando Refer\u00eancias",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Criando Seu Primeiro Post",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Estruturas de Blog no WordPress",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Criando o Modelo da P\u00e1gina de Posts - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Criando o Modelo da P\u00e1gina de Posts - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Criando o Modelo da P\u00e1gina de Posts - parte 3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Escrevendo Boas Postagens",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Categorias",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Criando a P\u00e1gina Blog",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - Usando o Widget de Posts - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - Usando o Widget de Posts - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - Finalizando o Layout da P\u00e1gina de Posts",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "12 - (Extra) Como trocar a foto de perfil do Usu\u00e1rio - Gravatar",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 9 Fazendo Uma Loja Virtual
#
# ----------- 09 - Fazendo Uma Loja Virtual
# 01 - Passos Iniciais e Conceitos Basicos - parte 1
# video_tree :: {'name': '01 - Passos Iniciais e Conceitos Basicos - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 01 - Passos Iniciais e Conceitos Basicos - parte 2
# video_tree :: {'name': '01 - Passos Iniciais e Conceitos Basicos - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Planejando o Seu Ecommerce
# video_tree :: {'name': '02 - Planejando o Seu Ecommerce', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Loja de Informatica (Astra) - parte 1 - P1
# video_tree :: {'name': '03 - Loja de Informatica (Astra) - parte 1 - P1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Loja de Informatica (Astra) - parte 2 - P1
# video_tree :: {'name': '03 - Loja de Informatica (Astra) - parte 2 - P1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Loja de Informatica (Astra) - parte 3 - P1
# video_tree :: {'name': '03 - Loja de Informatica (Astra) - parte 3 - P1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Loja de Informatica (Astra) - parte 1 - P2
# video_tree :: {'name': '04 - Loja de Informatica (Astra) - parte 1 - P2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Loja de Informatica (Astra) - parte 2 - P2
# video_tree :: {'name': '04 - Loja de Informatica (Astra) - parte 2 - P2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Paginas da Loja de Informatica (Astra) - parte 1 - P3
# video_tree :: {'name': '05 - Paginas da Loja de Informatica (Astra) - parte 1 - P3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Paginas da Loja de Informatica (Astra) - parte 2 - P3
# video_tree :: {'name': '05 - Paginas da Loja de Informatica (Astra) - parte 2 - P3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Loja de Informatica (Astra) - parte 1 - P4
# video_tree :: {'name': '06 - Loja de Informatica (Astra) - parte 1 - P4', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Loja de Informatica (Astra) - parte 2 - P4
# video_tree :: {'name': '06 - Loja de Informatica (Astra) - parte 2 - P4', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Loja de Informatica (Astra) - parte 3 - P4
# video_tree :: {'name': '06 - Loja de Informatica (Astra) - parte 3 - P4', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Loja de Informatica (Astra) - parte 1 - P5
# video_tree :: {'name': '07 - Loja de Informatica (Astra) - parte 1 - P5', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Loja de Informatica (Astra) - parte 2 - P5
# video_tree :: {'name': '07 - Loja de Informatica (Astra) - parte 2 - P5', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Loja de Informatica (Astra) - parte 3 - P5
# video_tree :: {'name': '07 - Loja de Informatica (Astra) - parte 3 - P5', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Ajustes Finais do Tema (Astra) P5
# video_tree :: {'name': '08 - Ajustes Finais do Tema (Astra) P5', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Loja de Doces (OceanWp) - parte 1 - P1
# video_tree :: {'name': '09 - Loja de Doces (OceanWp) - parte 1 - P1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 09 - Loja de Doces (OceanWp) - parte 2 - P1
# video_tree :: {'name': '09 - Loja de Doces (OceanWp) - parte 2 - P1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Pagina Inicial Loja de doces (OceanWP) - parte 1 - P2
# video_tree :: {'name': '10 - Pagina Inicial Loja de doces (OceanWP) - parte 1 - P2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 1 - P3
# video_tree :: {'name': '11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 1 - P3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 2 - P3
# video_tree :: {'name': '11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 2 - P3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 12 - Configurando Loja de Doces (OceanWP) - parte 1 - P4
# video_tree :: {'name': '12 - Configurando Loja de Doces (OceanWP) - parte 1 - P4', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 12 - Configurando Loja de Doces (OceanWP) - parte 2 - P4
# video_tree :: {'name': '12 - Configurando Loja de Doces (OceanWP) - parte 2 - P4', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 12 - Configurando Loja de Doces (OceanWP) - parte 3 - P4
# video_tree :: {'name': '12 - Configurando Loja de Doces (OceanWP) - parte 3 - P4', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 13 - Loja de Doces (OceanWP) - parte 1 - P5
# video_tree :: {'name': '13 - Loja de Doces (OceanWP) - parte 1 - P5', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 13 - Loja de Doces (OceanWP) - parte 2 - P5
# video_tree :: {'name': '13 - Loja de Doces (OceanWP) - parte 2 - P5', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 13 - Loja de Doces (OceanWP) - parte 3 - P5
# video_tree :: {'name': '13 - Loja de Doces (OceanWP) - parte 3 - P5', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 14 - Sistemas de Pagamentos - parte 1
# video_tree :: {'name': '14 - Sistemas de Pagamentos - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 14 - Sistemas de Pagamentos - parte 2
# video_tree :: {'name': '14 - Sistemas de Pagamentos - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 15 - Configurando SSL (IMPORTANTE) - parte 1
# video_tree :: {'name': '15 - Configurando SSL (IMPORTANTE) - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 15 - Configurando SSL (IMPORTANTE) - parte 2
# video_tree :: {'name': '15 - Configurando SSL (IMPORTANTE) - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Paginas da Loja de Informatica (Astra) - parte 3 - P3
# video_tree :: {'name': '05 - Paginas da Loja de Informatica (Astra) - parte 3 - P3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 10 - Pagina Inicial Loja de doces (OceanWP) - parte 2 - P2
# video_tree :: {'name': '10 - Pagina Inicial Loja de doces (OceanWP) - parte 2 - P2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "09 - Fazendo Uma Loja Virtual",
#     "number": 9,
#     "finalize_name": "09 - Fazendo Uma Loja Virtual",
#     "time_module": "56h40m00s",
#     "time_module_seconds": 204000,
#     "number_of_videos": 34,
#     "files": [
#         {
#             "name": "01 - Passos Iniciais e Conceitos Basicos - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "01 - Passos Iniciais e Conceitos Basicos - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Planejando o Seu Ecommerce",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Loja de Informatica (Astra) - parte 1 - P1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Loja de Informatica (Astra) - parte 2 - P1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Loja de Informatica (Astra) - parte 3 - P1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Loja de Informatica (Astra) - parte 1 - P2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Loja de Informatica (Astra) - parte 2 - P2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Paginas da Loja de Informatica (Astra) - parte 1 - P3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Paginas da Loja de Informatica (Astra) - parte 2 - P3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Loja de Informatica (Astra) - parte 1 - P4",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Loja de Informatica (Astra) - parte 2 - P4",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Loja de Informatica (Astra) - parte 3 - P4",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Loja de Informatica (Astra) - parte 1 - P5",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Loja de Informatica (Astra) - parte 2 - P5",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Loja de Informatica (Astra) - parte 3 - P5",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Ajustes Finais do Tema (Astra) P5",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Loja de Doces (OceanWp) - parte 1 - P1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "09 - Loja de Doces (OceanWp) - parte 2 - P1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "10 - Pagina Inicial Loja de doces (OceanWP) - parte 1 - P2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 1 - P3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 2 - P3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "12 - Configurando Loja de Doces (OceanWP) - parte 1 - P4",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "12 - Configurando Loja de Doces (OceanWP) - parte 2 - P4",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "12 - Configurando Loja de Doces (OceanWP) - parte 3 - P4",
# ...
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - \u00daltimas Configura\u00e7\u00f5es - Preparando para a Entrega - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "11 - \u00daltimas Configura\u00e7\u00f5es - Preparando para a Entrega - parte 3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "12 - Conclus\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 20 Análises de Sites de Alunos
#
# ----------- 20 - Análises de Sites de Alunos
# 02 - Site de Poker - Ivan
# video_tree :: {'name': '02 - Site de Poker - Ivan', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Site Institucional - Evandro
# video_tree :: {'name': '03 - Site Institucional - Evandro', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Site Institucional - Alto da Toca Baterias
# video_tree :: {'name': '04 - Site Institucional - Alto da Toca Baterias', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Site de Vendas de um Evento - Noemy - parte 1
# video_tree :: {'name': '05 - Site de Vendas de um Evento - Noemy - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Site de Vendas de um Evento - Noemy - parte 2
# video_tree :: {'name': '05 - Site de Vendas de um Evento - Noemy - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Página de Captura - Portfólio - Cristophe
# video_tree :: {'name': '06 - Página de Captura - Portfólio - Cristophe', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Site do Próprio Negócio - Renato Severo - cursoterapiafloral
# video_tree :: {'name': '07 - Site do Próprio Negócio - Renato Severo - cursoterapiafloral', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 08 - Site de Cursos de Dança - Ricardo Abelhas
# video_tree :: {'name': '08 - Site de Cursos de Dança - Ricardo Abelhas', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "20 - An\u00e1lises de Sites de Alunos",
#     "number": 20,
#     "finalize_name": "20 - An\u00e1lises de Sites de Alunos",
#     "time_module": "13h20m00s",
#     "time_module_seconds": 48000,
#     "number_of_videos": 8,
#     "files": [
#         {
#             "name": "02 - Site de Poker - Ivan",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Site Institucional - Evandro",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Site Institucional - Alto da Toca Baterias",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Site de Vendas de um Evento - Noemy - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Site de Vendas de um Evento - Noemy - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - P\u00e1gina de Captura - Portf\u00f3lio - Cristophe",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Site do Pr\u00f3prio Neg\u00f3cio - Renato Severo - cursoterapiafloral",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "08 - Site de Cursos de Dan\u00e7a - Ricardo Abelhas",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 21 MENTORIAS EM GRUPO
#
# ----------- 21 - MENTORIAS EM GRUPO
# 01 - MENTORIA EM GRUPO
# video_tree :: {'name': '01 - MENTORIA EM GRUPO', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - MENTORIA EM GRUPO
# video_tree :: {'name': '02 - MENTORIA EM GRUPO', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - MENTORIA EM GRUPO
# video_tree :: {'name': '03 - MENTORIA EM GRUPO', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - MENTORIA EM GRUPO
# video_tree :: {'name': '04 - MENTORIA EM GRUPO', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - MENTORIA EM GRUPO
# video_tree :: {'name': '05 - MENTORIA EM GRUPO', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "21 - MENTORIAS EM GRUPO",
#     "number": 21,
#     "finalize_name": "21 - MENTORIAS EM GRUPO",
#     "time_module": "08h20m00s",
#     "time_module_seconds": 30000,
#     "number_of_videos": 5,
#     "files": [
#         {
#             "name": "01 - MENTORIA EM GRUPO",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - MENTORIA EM GRUPO",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - MENTORIA EM GRUPO",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - MENTORIA EM GRUPO",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - MENTORIA EM GRUPO",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 22 MOBILE FIRST
#
# ----------- 22 - MOBILE FIRST
# 01 - Pense Mobile First! (AULÃO DE SEXTA)
# video_tree :: {'name': '01 - Pense Mobile First! (AULÃO DE SEXTA)', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Passo a Passo - Introdução
# video_tree :: {'name': '02 - Passo a Passo - Introdução', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Página Inicial - parte 1
# video_tree :: {'name': '03 - Página Inicial - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Página Inicial - parte 2
# video_tree :: {'name': '03 - Página Inicial - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Página Inicial - parte 3
# video_tree :: {'name': '03 - Página Inicial - parte 3', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Carrossel
# video_tree :: {'name': '04 - Carrossel', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Footer
# video_tree :: {'name': '05 - Footer', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - PopUps - parte 1
# video_tree :: {'name': '06 - PopUps - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - PopUps - parte 2
# video_tree :: {'name': '06 - PopUps - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "22 - MOBILE FIRST",
#     "number": 22,
#     "finalize_name": "22 - MOBILE FIRST",
#     "time_module": "15h00m00s",
#     "time_module_seconds": 54000,
#     "number_of_videos": 9,
#     "files": [
#         {
#             "name": "01 - Pense Mobile First! (AUL\u00c3O DE SEXTA)",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Passo a Passo - Introdu\u00e7\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - P\u00e1gina Inicial - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - P\u00e1gina Inicial - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - P\u00e1gina Inicial - parte 3",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Carrossel",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - Footer",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - PopUps - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - PopUps - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 23 Trabalhando de Forma Remota
#
# ----------- 23 - Trabalhando de Forma Remota
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Zoom
# video_tree :: {'name': '02 - Zoom', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Google Drive
# video_tree :: {'name': '03 - Google Drive', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Trello
# video_tree :: {'name': '04 - Trello', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - YouCanBookMe - parte 1
# video_tree :: {'name': '05 - YouCanBookMe - parte 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - YouCanBookMe - parte 2
# video_tree :: {'name': '05 - YouCanBookMe - parte 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 06 - Discord
# video_tree :: {'name': '06 - Discord', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 07 - Slack
# video_tree :: {'name': '07 - Slack', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "23 - Trabalhando de Forma Remota",
#     "number": 23,
#     "finalize_name": "23 - Trabalhando de Forma Remota",
#     "time_module": "13h20m00s",
#     "time_module_seconds": 48000,
#     "number_of_videos": 8,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Zoom",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Google Drive",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Trello",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - YouCanBookMe - parte 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - YouCanBookMe - parte 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "06 - Discord",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "07 - Slack",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 24 Site Anitta
#
# ----------- 24 - Site Anitta
# 01 - Construção do Layout
# video_tree :: {'name': '01 - Construção do Layout', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Mouse Track e 3D Tilt
# video_tree :: {'name': '02 - Mouse Track e 3D Tilt', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Criando um PopUp Acionado por Botão
# video_tree :: {'name': '03 - Criando um PopUp Acionado por Botão', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "24 - Site Anitta - (Efeitos de Movimento e PopUp)",
#     "number": 24,
#     "finalize_name": "24 - Site Anitta",
#     "time_module": "05h00m00s",
#     "time_module_seconds": 18000,
#     "number_of_videos": 3,
#     "files": [
#         {
#             "name": "01 - Constru\u00e7\u00e3o do Layout",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Mouse Track e 3D Tilt",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Criando um PopUp Acionado por Bot\u00e3o",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 25 Teoria das Cores
#
# ----------- 25 - Teoria das Cores
# 08 - Atualização - Salvando as Cores Padrões no Elementor
# video_tree :: {'name': '08 - Atualização - Salvando as Cores Padrões no Elementor', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "25 - Teoria das Cores",
#     "number": 25,
#     "finalize_name": "25 - Teoria das Cores",
#     "time_module": "01h40m00s",
#     "time_module_seconds": 6000,
#     "number_of_videos": 1,
#     "files": [
#         {
#             "name": "08 - Atualiza\u00e7\u00e3o - Salvando as Cores Padr\u00f5es no Elementor",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 26 Como Criar um Logotipo Simples
#
# ----------- 26 - Como Criar um Logotipo Simples
# 01 - Canva
# video_tree :: {'name': '01 - Canva', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Logotipo - Modelo 1
# video_tree :: {'name': '02 - Logotipo - Modelo 1', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Logotipo - Modelo 2
# video_tree :: {'name': '03 - Logotipo - Modelo 2', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 04 - Tirando o Fundo do Logotipo e Algumas Dicas
# video_tree :: {'name': '04 - Tirando o Fundo do Logotipo e Algumas Dicas', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 05 - Bônu - Vintepila e Workana
# video_tree :: {'name': '05 - Bônu - Vintepila e Workana', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "26 - Como Criar um Logotipo Simples",
#     "number": 26,
#     "finalize_name": "26 - Como Criar um Logotipo Simples",
#     "time_module": "08h20m00s",
#     "time_module_seconds": 30000,
#     "number_of_videos": 5,
#     "files": [
#         {
#             "name": "01 - Canva",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Logotipo - Modelo 1",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Logotipo - Modelo 2",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "04 - Tirando o Fundo do Logotipo e Algumas Dicas",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "05 - B\u00f4nu - Vintepila e Workana",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }
#
# ==================== 27 Maratona Lucrando com Sites
#
# ----------- 27 - Maratona Lucrando com Sites
# 01 - Por que um site vale BEM mais que R$2.500
# video_tree :: {'name': '01 - Por que um site vale BEM mais que R$2.500', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 02 - Ferramentas Necessárias para Criar um Site Profissional
# video_tree :: {'name': '02 - Ferramentas Necessárias para Criar um Site Profissional', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
# 03 - Como fechar seus projetos com Clientes!
# video_tree :: {'name': '03 - Como fechar seus projetos com Clientes!', 'time_video': '01h40m00s', 'time_video_seconds': 6000}
#
#
#  => module_tree ::
# {
#     "name": "27 - Maratona Lucrando com Sites",
#     "number": 27,
#     "finalize_name": "27 - Maratona Lucrando com Sites",
#     "time_module": "05h00m00s",
#     "time_module_seconds": 18000,
#     "number_of_videos": 3,
#     "files": [
#         {
#             "name": "01 - Por que um site vale BEM mais que R$2.500",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "02 - Ferramentas Necess\u00e1rias para Criar um Site Profissional",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         },
#         {
#             "name": "03 - Como fechar seus projetos com Clientes!",
#             "time_video": "01h40m00s",
#             "time_video_seconds": 6000
#         }
#     ]
# }

# %%
# itera para pegar tempo total
for el in course_tree['modules']:
    course_tree['time_course_seconds'] += el['time_module_seconds']
    course_tree['number_of_modules'] += 1

h, m, s = convert(course_tree['time_course_seconds'])
course_tree['time_course'] = get_convert(h, m, s)

# Salvar em JSON
with open('data.json', 'w') as fp:
    json.dump(course_tree, fp)

# %% [markdown]
# ## Create `README-GLOBAL.md`

# %%
with open("README-GLOBAL.md",'w', encoding = 'utf-8') as f:
    f.write("# {}\n\n".format(course_tree['name_course']))
    f.write("Tempo: {} || Quantidade de Módulos {}\n\n".format(
        course_tree['time_course'], course_tree['number_of_modules'],))
    f.write("## File Tree\n\n")
    for el in course_tree['modules']:
        f.write("├─── {} ({})\n".format(el['finalize_name'], el['time_module']))
        for il in el['files']:
            f.write("│       {} ({})\n".format(il['name'], il['time_video']))
        f.write('│\n')

# %% [markdown]
# ## Create individual `README.md` to each module

# %%
# Escrevendo N Modulos
for el in course_tree['modules']:
    # str(el['number']).zfill(2) + '-'
    file_module_name = el['finalize_name'] + '.md'
    with open(file_module_name, 'w', encoding = 'utf-8') as f:
        f.write("# {}\n\n".format(el['finalize_name']))
        f.write("Tempo: {} || Quantidade de Vídeos {}\n\n".format(
        el['time_module'], el['number_of_videos'],))
        for il in el['files']:
            f.write("## {} ({})\n\n\n\n".format(il['name'], il['time_video']))
