# %% [markdown]
# # course-file-tree-generator
#
# Gerar README global e Readme de cada módulo de pastas de um curso
#
#
# # Last Update
#
# + 11/11/2022
#   - Será somente este arquivo
#   - A cada novo curso, que precisar ter um novo script para separar núero de nome do arquivo, SALVE no comentário
#   - Está ordenando tudo

# %%
import os
import json

import moviepy.editor

# %%
 # windows :: \\, linux: /
    
from sys import platform
if platform == "linux" or platform == "linux2":
    print('linux')
    separator = '/'
elif platform == "darwin":
    print('OS X')
    separator = '/'
elif platform == "win32":
    print('windows')
    separator = '\\'

separator
# Out:
# linux
# '/'

# %% [markdown]
# # Snippets

# %%
# Converts into more readable format 
def convert(seconds):
    hours = seconds // 3600
    seconds %= 3600
    mins = seconds // 60
    seconds %= 60
    return hours, mins, seconds

# format: 00h00m00s
def get_convert(hours, mins, secs):
    if(hours == 0):
        return str(mins).zfill(2) + 'm' + str(secs).zfill(2) + 's'
    else:
        return str(hours).zfill(2) + 'h' + str(mins).zfill(2) + 'm' + str(secs).zfill(2) + 's'

# get duraction of video-file
def get_duraction_of_file(filepath):
    video_duration = 6000
    video = moviepy.editor.VideoFileClip(filepath)
    video_duration = int(video.duration)
    hours, mins, secs = convert(video_duration)
    return get_convert(hours, mins, secs), video_duration

# %%
def list_files(dir):
    r = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            r.append(os.path.join(root, name))
    return r

# %% [markdown]
# # Get Root

# %%
# Pga o nome da pasta raiz. Deve ser o nome do curso
root_course = os.getcwd().split(separator)[-1]
print('Nome do curso:\n==>', root_course)
# Out:
# Nome do curso:
# ==> Raiam Santos - A Arte do Networking

# %% [markdown]
# # Get Folders

# %%
# Get all sub-folders of actual directory
path = '.'
all_directory_files_contents = os.listdir(path)

# Filter Directories Only
all_dirs = list(filter(lambda x: os.path.isdir(x), all_directory_files_contents))
all_dirs

# Remove folders invalids
list_of_exlcude_dirs = ['.ipynb_checkpoints']

for el in list_of_exlcude_dirs:
    if(el in all_dirs):
        all_dirs.remove(el)
        
# Show result
all_dirs
# Out:
# ['Módulo 8 - Network Online',
#  'Módulo 4 - Linguagem Corporal',
#  'Módulo 3 - Case Studies e Conceitos',
#  'Módulo 10 - Network Internacional',
#  'Módulo 2 - Microhabitos',
#  'Módulo 1 - Introdução',
#  'Módulo 5 - Linguagem Facial',
#  'Módulo 9 - Eventos e Conferencias',
#  'Módulo 7 - Network High Level',
#  'Módulo 6 - Expandindo a Rede']

# %% [markdown]
# ## Sort Folders (Insira código aqui) in Dict Structure
#
# **A função `get_number_of_folder` muda para cada curso: é como pegar o número do módulo no nomes das pastas**
#
# Infelizmente, vai ler na ordem, 1 => 10 => 11 ... , 2 => 20 => 21 ,... ,  e nao queremos isso. ENtâ vamos criar uma lsita de tuplas, onde cada tulpla te tamanho 3 e segue a ordem:
#
# ````
# (numero, nome-completo, nome-sem-enumeracao)
# ````
#
# **OBS:** Deverá ser alterado apra cada estrutura de pasta

# %%
ab = 'Módulo 6 - Expandindo a Rede'

ab.split('-')[0].split(' ')[1].zfill(2)
# Out:
# '06'

# %%
get_number_of_folder(ab)
# Out:
# '06'

# %%
# Essas regras vão variar para cada curso
def get_number_of_folder(dir_name):
    ### Se a pasta for tivre o nome ...
    ## 'Módulo 1 - Introdução'
    ## CÓDIGO: dir_name.split('-')[0].split(' ')[1].zfill(2)
    
    
    return dir_name.split('-')[0].split(' ')[1].zfill(2)

def get_name_of_folder(dir_name):
    ### Se a pasta for tivre o nome ...
    ## 'Módulo 1 - Introdução'
    ## CÓDIGO: dir_name.split('-')[1].strip()
    
    
    return dir_name.split('-')[1].strip()

# %%
# maping_sorted_dict = deve terminar como uma lsita de tuplas 
#   no seguinte formato:
#   (number_int, (nome_full_pasta, nome_modulo))
maping_sorted_dict = {}
for el in all_dirs:
    number_str = get_number_of_folder(el)
    maping_sorted_dict[int(number_str)] = (el, get_name_of_folder(el))

maping_sorted_dict = sorted(maping_sorted_dict.items(), key=lambda x: x[0])
maping_sorted_dict
# Out:
# [(1, ('Módulo 1 - Introdução', 'Introdução')),
#  (2, ('Módulo 2 - Microhabitos', 'Microhabitos')),
#  (3, ('Módulo 3 - Case Studies e Conceitos', 'Case Studies e Conceitos')),
#  (4, ('Módulo 4 - Linguagem Corporal', 'Linguagem Corporal')),
#  (5, ('Módulo 5 - Linguagem Facial', 'Linguagem Facial')),
#  (6, ('Módulo 6 - Expandindo a Rede', 'Expandindo a Rede')),
#  (7, ('Módulo 7 - Network High Level', 'Network High Level')),
#  (8, ('Módulo 8 - Network Online', 'Network Online')),
#  (9, ('Módulo 9 - Eventos e Conferencias', 'Eventos e Conferencias')),
#  (10, ('Módulo 10 - Network Internacional', 'Network Internacional'))]

# %% [markdown]
# # Execute Processe - Generate Folders Structure
#
# Devo iterarra e criar uma super esttutura de ados que tera´todos os dados, e no final, eu faço o write nos arquivos, tanto no Readme quanto no repsctivo course/01-module.md
#
# curso total = tempo x
#
# ````
# {
#     name_course: root,
#     time_course: 00:00:00,
#     time_course_seconds: 0,
#     number_of_modules: 0,
#     modules: [
#         {
#             name: 'module-01-xxx',
#             number: '1',
#             time_module: 00:00:00,
#             time_module_seconds: 0,
#             number_of_videos: 0,
#             files: [
#                 {
#                     name: 'file-01'
#                     time_video: 00:00:00,
#                 },
#                 ...
#             ],
#         },
#         ...
#     ],
# }
# ````json

# %%
# Recuperando todas as pastas do curso
folders_sorted_of_course = maping_sorted_dict
folders_sorted_of_course
# Out:
# [(1, ('Módulo 1 - Introdução', 'Introdução')),
#  (2, ('Módulo 2 - Microhabitos', 'Microhabitos')),
#  (3, ('Módulo 3 - Case Studies e Conceitos', 'Case Studies e Conceitos')),
#  (4, ('Módulo 4 - Linguagem Corporal', 'Linguagem Corporal')),
#  (5, ('Módulo 5 - Linguagem Facial', 'Linguagem Facial')),
#  (6, ('Módulo 6 - Expandindo a Rede', 'Expandindo a Rede')),
#  (7, ('Módulo 7 - Network High Level', 'Network High Level')),
#  (8, ('Módulo 8 - Network Online', 'Network Online')),
#  (9, ('Módulo 9 - Eventos e Conferencias', 'Eventos e Conferencias')),
#  (10, ('Módulo 10 - Network Internacional', 'Network Internacional'))]

# %%
# Ordena o attr 'files' pelo name. Tem que converter para int ou .zfill(2)
def sort_module_tree_files(module_tree):
    module_tree['files'] = sorted(
        module_tree['files'], key=lambda x: x['name'].zfill(2)
    )
    return module_tree

# %%
# Inicializar estrutura do curso inteiro
course_tree = {
    'name_course': root_course,
    'time_course': '',
    'time_course_seconds': 0,
    'number_of_modules': 0,
    'modules' : [],
}

# Files to filter
filter_videos_files = ['mp4','ts', 'MP4']

# Iterar sobre as pastas do curso
# filepath_module com numero, sem numero
for number_of_module, filepath_module in folders_sorted_of_course:
    
    filepath_name, numberless_name = filepath_module[0], filepath_module[1]
    print('\n====================', number_of_module, numberless_name, '\n')
    
    # initialize module tree
    module_tree = {
        'name': filepath_name,
        'number': number_of_module,
        'finalize_name': str(number_of_module).zfill(2) + ' - ' + numberless_name,
        'time_module': '',
        'time_module_seconds': 0,
        'number_of_videos': 0,
        'files': [],
    }
    print('-----------',  str(number_of_module).zfill(2) + ' - ' + numberless_name)
    
    # Get and  Analyse videos
    video_files = list(filter(lambda x: x.split('.')[-1] in filter_videos_files, list_files(filepath_name)))
    for el in video_files:
        video_name = (os.path.splitext(el)[0]).split(separator)[-1]
        print(video_name)
        video_tree = {
            'name': '',
            'time_video': '',
            'time_video_seconds': '',
        }
        time_string, video_seconds = get_duraction_of_file(el)
        # save video data
        video_tree['time_video_seconds'] = video_seconds
        video_tree['time_video'] = time_string
        video_tree['name'] = video_name
        print('video_tree ::', video_tree, '\n')
        # save in module data
        module_tree['files'].append(video_tree)
        module_tree['number_of_videos'] += 1
        module_tree['time_module_seconds'] += video_seconds

    h, m, s = convert(module_tree['time_module_seconds'])
    module_tree['time_module'] = get_convert(h, m, s)
    
    # Ordena os 'files' do 'module_tree'
    #   , pois as vezes não está ordenado
    module_tree = sort_module_tree_files(module_tree)
    
    # END
    print('\n => module_tree ::')
    print(json.dumps(module_tree, indent=4))
    
    course_tree['modules'].append(module_tree)
# Out:
# ==================== 1 Introdução
#
# ----------- 01 - Introdução
# 1
# video_tree :: {'name': '1', 'time_video': '01m52s', 'time_video_seconds': 112}
#
# 6
# video_tree :: {'name': '6', 'time_video': '05m08s', 'time_video_seconds': 308}
#
# 3
# video_tree :: {'name': '3', 'time_video': '04m12s', 'time_video_seconds': 252}
#
# 5
# video_tree :: {'name': '5', 'time_video': '01m49s', 'time_video_seconds': 109}
#
# 4
# video_tree :: {'name': '4', 'time_video': '09m54s', 'time_video_seconds': 594}
#
# 2
# video_tree :: {'name': '2', 'time_video': '03m54s', 'time_video_seconds': 234}
#
# 7
# video_tree :: {'name': '7', 'time_video': '01m53s', 'time_video_seconds': 113}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 1 - Introdu\u00e7\u00e3o",
#     "number": 1,
#     "finalize_name": "01 - Introdu\u00e7\u00e3o",
#     "time_module": "28m42s",
#     "time_module_seconds": 1722,
#     "number_of_videos": 7,
#     "files": [
#         {
#             "name": "1",
#             "time_video": "01m52s",
#             "time_video_seconds": 112
#         },
#         {
#             "name": "2",
#             "time_video": "03m54s",
#             "time_video_seconds": 234
#         },
#         {
#             "name": "3",
#             "time_video": "04m12s",
#             "time_video_seconds": 252
#         },
#         {
#             "name": "4",
#             "time_video": "09m54s",
#             "time_video_seconds": 594
#         },
#         {
#             "name": "5",
#             "time_video": "01m49s",
#             "time_video_seconds": 109
#         },
#         {
#             "name": "6",
#             "time_video": "05m08s",
#             "time_video_seconds": 308
#         },
#         {
#             "name": "7",
#             "time_video": "01m53s",
#             "time_video_seconds": 113
#         }
#     ]
# }
#
# ==================== 2 Microhabitos
#
# ----------- 02 - Microhabitos
# 16
# video_tree :: {'name': '16', 'time_video': '02m16s', 'time_video_seconds': 136}
#
# 13
# video_tree :: {'name': '13', 'time_video': '02m03s', 'time_video_seconds': 123}
#
# 11
# video_tree :: {'name': '11', 'time_video': '02m24s', 'time_video_seconds': 144}
#
# 17
# video_tree :: {'name': '17', 'time_video': '02m19s', 'time_video_seconds': 139}
#
# 18
# video_tree :: {'name': '18', 'time_video': '01m40s', 'time_video_seconds': 100}
#
# 10
# video_tree :: {'name': '10', 'time_video': '02m28s', 'time_video_seconds': 148}
#
# 12
# video_tree :: {'name': '12', 'time_video': '02m29s', 'time_video_seconds': 149}
#
# 9
# video_tree :: {'name': '9', 'time_video': '02m00s', 'time_video_seconds': 120}
#
# 15
# video_tree :: {'name': '15', 'time_video': '02m39s', 'time_video_seconds': 159}
#
# 14
# video_tree :: {'name': '14', 'time_video': '03m32s', 'time_video_seconds': 212}
#
# 8
# video_tree :: {'name': '8', 'time_video': '02m21s', 'time_video_seconds': 141}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 2 - Microhabitos",
#     "number": 2,
#     "finalize_name": "02 - Microhabitos",
#     "time_module": "26m11s",
#     "time_module_seconds": 1571,
#     "number_of_videos": 11,
#     "files": [
#         {
#             "name": "8",
#             "time_video": "02m21s",
#             "time_video_seconds": 141
#         },
#         {
#             "name": "9",
#             "time_video": "02m00s",
#             "time_video_seconds": 120
#         },
#         {
#             "name": "10",
#             "time_video": "02m28s",
#             "time_video_seconds": 148
#         },
#         {
#             "name": "11",
#             "time_video": "02m24s",
#             "time_video_seconds": 144
#         },
#         {
#             "name": "12",
#             "time_video": "02m29s",
#             "time_video_seconds": 149
#         },
#         {
#             "name": "13",
#             "time_video": "02m03s",
#             "time_video_seconds": 123
#         },
#         {
#             "name": "14",
#             "time_video": "03m32s",
#             "time_video_seconds": 212
#         },
#         {
#             "name": "15",
#             "time_video": "02m39s",
#             "time_video_seconds": 159
#         },
#         {
#             "name": "16",
#             "time_video": "02m16s",
#             "time_video_seconds": 136
#         },
#         {
#             "name": "17",
#             "time_video": "02m19s",
#             "time_video_seconds": 139
#         },
#         {
#             "name": "18",
#             "time_video": "01m40s",
#             "time_video_seconds": 100
#         }
#     ]
# }
#
# ==================== 3 Case Studies e Conceitos
#
# ----------- 03 - Case Studies e Conceitos
# 28
# video_tree :: {'name': '28', 'time_video': '05m27s', 'time_video_seconds': 327}
#
# 33
# video_tree :: {'name': '33', 'time_video': '03m19s', 'time_video_seconds': 199}
#
# 23
# video_tree :: {'name': '23', 'time_video': '03m46s', 'time_video_seconds': 226}
#
# 24
# video_tree :: {'name': '24', 'time_video': '01m30s', 'time_video_seconds': 90}
#
# 21
# video_tree :: {'name': '21', 'time_video': '04m27s', 'time_video_seconds': 267}
#
# 26
# video_tree :: {'name': '26', 'time_video': '03m39s', 'time_video_seconds': 219}
#
# 19
# video_tree :: {'name': '19', 'time_video': '01m46s', 'time_video_seconds': 106}
#
# 30
# video_tree :: {'name': '30', 'time_video': '05m54s', 'time_video_seconds': 354}
#
# 20
# video_tree :: {'name': '20', 'time_video': '02m46s', 'time_video_seconds': 166}
#
# 27
# video_tree :: {'name': '27', 'time_video': '04m20s', 'time_video_seconds': 260}
#
# 29
# video_tree :: {'name': '29', 'time_video': '02m18s', 'time_video_seconds': 138}
#
# 31
# video_tree :: {'name': '31', 'time_video': '02m03s', 'time_video_seconds': 123}
#
# 35
# video_tree :: {'name': '35', 'time_video': '03m38s', 'time_video_seconds': 218}
#
# 22
# video_tree :: {'name': '22', 'time_video': '03m21s', 'time_video_seconds': 201}
#
# 32
# video_tree :: {'name': '32', 'time_video': '02m57s', 'time_video_seconds': 177}
#
# 34
# video_tree :: {'name': '34', 'time_video': '03m32s', 'time_video_seconds': 212}
#
# 36
# video_tree :: {'name': '36', 'time_video': '03m58s', 'time_video_seconds': 238}
#
# 25
# video_tree :: {'name': '25', 'time_video': '03m29s', 'time_video_seconds': 209}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 3 - Case Studies e Conceitos",
#     "number": 3,
#     "finalize_name": "03 - Case Studies e Conceitos",
#     "time_module": "01h02m10s",
#     "time_module_seconds": 3730,
#     "number_of_videos": 18,
#     "files": [
#         {
#             "name": "19",
#             "time_video": "01m46s",
#             "time_video_seconds": 106
#         },
#         {
#             "name": "20",
#             "time_video": "02m46s",
#             "time_video_seconds": 166
#         },
#         {
#             "name": "21",
#             "time_video": "04m27s",
#             "time_video_seconds": 267
#         },
#         {
#             "name": "22",
#             "time_video": "03m21s",
#             "time_video_seconds": 201
#         },
#         {
#             "name": "23",
#             "time_video": "03m46s",
#             "time_video_seconds": 226
#         },
#         {
#             "name": "24",
#             "time_video": "01m30s",
#             "time_video_seconds": 90
#         },
#         {
#             "name": "25",
#             "time_video": "03m29s",
#             "time_video_seconds": 209
#         },
#         {
#             "name": "26",
#             "time_video": "03m39s",
#             "time_video_seconds": 219
#         },
#         {
#             "name": "27",
#             "time_video": "04m20s",
#             "time_video_seconds": 260
#         },
#         {
#             "name": "28",
#             "time_video": "05m27s",
#             "time_video_seconds": 327
#         },
#         {
#             "name": "29",
#             "time_video": "02m18s",
#             "time_video_seconds": 138
#         },
#         {
#             "name": "30",
#             "time_video": "05m54s",
#             "time_video_seconds": 354
#         },
#         {
#             "name": "31",
#             "time_video": "02m03s",
#             "time_video_seconds": 123
#         },
#         {
#             "name": "32",
#             "time_video": "02m57s",
#             "time_video_seconds": 177
#         },
#         {
#             "name": "33",
#             "time_video": "03m19s",
#             "time_video_seconds": 199
#         },
#         {
#             "name": "34",
#             "time_video": "03m32s",
#             "time_video_seconds": 212
#         },
#         {
#             "name": "35",
#             "time_video": "03m38s",
#             "time_video_seconds": 218
#         },
#         {
#             "name": "36",
#             "time_video": "03m58s",
#             "time_video_seconds": 238
#         }
#     ]
# }
#
# ==================== 4 Linguagem Corporal
#
# ----------- 04 - Linguagem Corporal
# 39
# video_tree :: {'name': '39', 'time_video': '06m18s', 'time_video_seconds': 378}
#
# 37
# video_tree :: {'name': '37', 'time_video': '05m21s', 'time_video_seconds': 321}
#
# 38
# video_tree :: {'name': '38', 'time_video': '04m29s', 'time_video_seconds': 269}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 4 - Linguagem Corporal",
#     "number": 4,
#     "finalize_name": "04 - Linguagem Corporal",
#     "time_module": "16m08s",
#     "time_module_seconds": 968,
#     "number_of_videos": 3,
#     "files": [
#         {
#             "name": "37",
#             "time_video": "05m21s",
#             "time_video_seconds": 321
#         },
#         {
#             "name": "38",
#             "time_video": "04m29s",
#             "time_video_seconds": 269
#         },
#         {
#             "name": "39",
#             "time_video": "06m18s",
#             "time_video_seconds": 378
#         }
#     ]
# }
#
# ==================== 5 Linguagem Facial
#
# ----------- 05 - Linguagem Facial
# 41
# video_tree :: {'name': '41', 'time_video': '00m43s', 'time_video_seconds': 43}
#
# 53
# video_tree :: {'name': '53', 'time_video': '01m04s', 'time_video_seconds': 64}
#
# 50
# video_tree :: {'name': '50', 'time_video': '01m51s', 'time_video_seconds': 111}
#
# 52
# video_tree :: {'name': '52', 'time_video': '03m34s', 'time_video_seconds': 214}
#
# 43
# video_tree :: {'name': '43', 'time_video': '01m03s', 'time_video_seconds': 63}
#
# 44
# video_tree :: {'name': '44', 'time_video': '01m07s', 'time_video_seconds': 67}
#
# 46
# video_tree :: {'name': '46', 'time_video': '00m58s', 'time_video_seconds': 58}
#
# 40
# video_tree :: {'name': '40', 'time_video': '02m02s', 'time_video_seconds': 122}
#
# 48
# video_tree :: {'name': '48', 'time_video': '02m56s', 'time_video_seconds': 176}
#
# 42
# video_tree :: {'name': '42', 'time_video': '01m07s', 'time_video_seconds': 67}
#
# 45
# video_tree :: {'name': '45', 'time_video': '02m14s', 'time_video_seconds': 134}
#
# 49
# video_tree :: {'name': '49', 'time_video': '02m30s', 'time_video_seconds': 150}
#
# 51
# video_tree :: {'name': '51', 'time_video': '02m21s', 'time_video_seconds': 141}
#
# 47
# video_tree :: {'name': '47', 'time_video': '01m08s', 'time_video_seconds': 68}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 5 - Linguagem Facial",
#     "number": 5,
#     "finalize_name": "05 - Linguagem Facial",
#     "time_module": "24m38s",
#     "time_module_seconds": 1478,
#     "number_of_videos": 14,
#     "files": [
#         {
#             "name": "40",
#             "time_video": "02m02s",
#             "time_video_seconds": 122
#         },
#         {
#             "name": "41",
#             "time_video": "00m43s",
#             "time_video_seconds": 43
#         },
#         {
#             "name": "42",
#             "time_video": "01m07s",
#             "time_video_seconds": 67
#         },
#         {
#             "name": "43",
#             "time_video": "01m03s",
#             "time_video_seconds": 63
#         },
#         {
#             "name": "44",
#             "time_video": "01m07s",
#             "time_video_seconds": 67
#         },
#         {
#             "name": "45",
#             "time_video": "02m14s",
#             "time_video_seconds": 134
#         },
#         {
#             "name": "46",
#             "time_video": "00m58s",
#             "time_video_seconds": 58
#         },
#         {
#             "name": "47",
#             "time_video": "01m08s",
#             "time_video_seconds": 68
#         },
#         {
#             "name": "48",
#             "time_video": "02m56s",
#             "time_video_seconds": 176
#         },
#         {
#             "name": "49",
#             "time_video": "02m30s",
#             "time_video_seconds": 150
#         },
#         {
#             "name": "50",
#             "time_video": "01m51s",
#             "time_video_seconds": 111
#         },
#         {
#             "name": "51",
#             "time_video": "02m21s",
#             "time_video_seconds": 141
#         },
#         {
#             "name": "52",
#             "time_video": "03m34s",
#             "time_video_seconds": 214
#         },
#         {
#             "name": "53",
#             "time_video": "01m04s",
#             "time_video_seconds": 64
#         }
#     ]
# }
#
# ==================== 6 Expandindo a Rede
#
# ----------- 06 - Expandindo a Rede
# 54
# video_tree :: {'name': '54', 'time_video': '03m37s', 'time_video_seconds': 217}
#
# 56
# video_tree :: {'name': '56', 'time_video': '02m55s', 'time_video_seconds': 175}
#
# 55
# video_tree :: {'name': '55', 'time_video': '12m22s', 'time_video_seconds': 742}
#
# 57
# video_tree :: {'name': '57', 'time_video': '03m46s', 'time_video_seconds': 226}
#
# 58
# video_tree :: {'name': '58', 'time_video': '09m12s', 'time_video_seconds': 552}
#
# 59
# video_tree :: {'name': '59', 'time_video': '04m08s', 'time_video_seconds': 248}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 6 - Expandindo a Rede",
#     "number": 6,
#     "finalize_name": "06 - Expandindo a Rede",
#     "time_module": "36m00s",
#     "time_module_seconds": 2160,
#     "number_of_videos": 6,
#     "files": [
#         {
#             "name": "54",
#             "time_video": "03m37s",
#             "time_video_seconds": 217
#         },
#         {
#             "name": "55",
#             "time_video": "12m22s",
#             "time_video_seconds": 742
#         },
#         {
#             "name": "56",
#             "time_video": "02m55s",
#             "time_video_seconds": 175
#         },
#         {
#             "name": "57",
#             "time_video": "03m46s",
#             "time_video_seconds": 226
#         },
#         {
#             "name": "58",
#             "time_video": "09m12s",
#             "time_video_seconds": 552
#         },
#         {
#             "name": "59",
#             "time_video": "04m08s",
#             "time_video_seconds": 248
#         }
#     ]
# }
#
# ==================== 7 Network High Level
#
# ----------- 07 - Network High Level
# 63
# video_tree :: {'name': '63', 'time_video': '04m50s', 'time_video_seconds': 290}
#
# 71
# video_tree :: {'name': '71', 'time_video': '02m56s', 'time_video_seconds': 176}
#
# 70
# video_tree :: {'name': '70', 'time_video': '05m11s', 'time_video_seconds': 311}
#
# 64
# video_tree :: {'name': '64', 'time_video': '02m29s', 'time_video_seconds': 149}
#
# 72
# video_tree :: {'name': '72', 'time_video': '02m48s', 'time_video_seconds': 168}
#
# 66
# video_tree :: {'name': '66', 'time_video': '00m42s', 'time_video_seconds': 42}
#
# 65
# video_tree :: {'name': '65', 'time_video': '02m18s', 'time_video_seconds': 138}
#
# 67
# video_tree :: {'name': '67', 'time_video': '01m52s', 'time_video_seconds': 112}
#
# 68
# video_tree :: {'name': '68', 'time_video': '01m46s', 'time_video_seconds': 106}
#
# 62
# video_tree :: {'name': '62', 'time_video': '02m22s', 'time_video_seconds': 142}
#
# 69
# video_tree :: {'name': '69', 'time_video': '02m39s', 'time_video_seconds': 159}
#
# 61
# video_tree :: {'name': '61', 'time_video': '05m20s', 'time_video_seconds': 320}
#
# 60
# video_tree :: {'name': '60', 'time_video': '01m59s', 'time_video_seconds': 119}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 7 - Network High Level",
#     "number": 7,
#     "finalize_name": "07 - Network High Level",
#     "time_module": "37m12s",
#     "time_module_seconds": 2232,
#     "number_of_videos": 13,
#     "files": [
#         {
#             "name": "60",
#             "time_video": "01m59s",
#             "time_video_seconds": 119
#         },
#         {
#             "name": "61",
#             "time_video": "05m20s",
#             "time_video_seconds": 320
#         },
#         {
#             "name": "62",
#             "time_video": "02m22s",
#             "time_video_seconds": 142
#         },
#         {
#             "name": "63",
#             "time_video": "04m50s",
#             "time_video_seconds": 290
#         },
#         {
#             "name": "64",
#             "time_video": "02m29s",
#             "time_video_seconds": 149
#         },
#         {
#             "name": "65",
#             "time_video": "02m18s",
#             "time_video_seconds": 138
#         },
#         {
#             "name": "66",
#             "time_video": "00m42s",
#             "time_video_seconds": 42
#         },
#         {
#             "name": "67",
#             "time_video": "01m52s",
#             "time_video_seconds": 112
#         },
#         {
#             "name": "68",
#             "time_video": "01m46s",
#             "time_video_seconds": 106
#         },
#         {
#             "name": "69",
#             "time_video": "02m39s",
#             "time_video_seconds": 159
#         },
#         {
#             "name": "70",
#             "time_video": "05m11s",
#             "time_video_seconds": 311
#         },
#         {
#             "name": "71",
#             "time_video": "02m56s",
#             "time_video_seconds": 176
#         },
#         {
#             "name": "72",
#             "time_video": "02m48s",
#             "time_video_seconds": 168
#         }
#     ]
# }
#
# ==================== 8 Network Online
#
# ----------- 08 - Network Online
# 77
# video_tree :: {'name': '77', 'time_video': '04m56s', 'time_video_seconds': 296}
#
# 79
# video_tree :: {'name': '79', 'time_video': '05m05s', 'time_video_seconds': 305}
#
# 78
# video_tree :: {'name': '78', 'time_video': '06m22s', 'time_video_seconds': 382}
#
# 75
# video_tree :: {'name': '75', 'time_video': '10m31s', 'time_video_seconds': 631}
#
# 74
# video_tree :: {'name': '74', 'time_video': '13m31s', 'time_video_seconds': 811}
#
# 76
# video_tree :: {'name': '76', 'time_video': '14m54s', 'time_video_seconds': 894}
#
# 73
# video_tree :: {'name': '73', 'time_video': '04m41s', 'time_video_seconds': 281}
#
# 80
# video_tree :: {'name': '80', 'time_video': '02m48s', 'time_video_seconds': 168}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 8 - Network Online",
#     "number": 8,
#     "finalize_name": "08 - Network Online",
#     "time_module": "01h02m48s",
#     "time_module_seconds": 3768,
#     "number_of_videos": 8,
#     "files": [
#         {
#             "name": "73",
#             "time_video": "04m41s",
#             "time_video_seconds": 281
#         },
#         {
#             "name": "74",
#             "time_video": "13m31s",
#             "time_video_seconds": 811
#         },
#         {
#             "name": "75",
#             "time_video": "10m31s",
#             "time_video_seconds": 631
#         },
#         {
#             "name": "76",
#             "time_video": "14m54s",
#             "time_video_seconds": 894
#         },
#         {
#             "name": "77",
#             "time_video": "04m56s",
#             "time_video_seconds": 296
#         },
#         {
#             "name": "78",
#             "time_video": "06m22s",
#             "time_video_seconds": 382
#         },
#         {
#             "name": "79",
#             "time_video": "05m05s",
#             "time_video_seconds": 305
#         },
#         {
#             "name": "80",
#             "time_video": "02m48s",
#             "time_video_seconds": 168
#         }
#     ]
# }
#
# ==================== 9 Eventos e Conferencias
#
# ----------- 09 - Eventos e Conferencias
# 87
# video_tree :: {'name': '87', 'time_video': '03m01s', 'time_video_seconds': 181}
#
# 85
# video_tree :: {'name': '85', 'time_video': '06m48s', 'time_video_seconds': 408}
#
# 89
# video_tree :: {'name': '89', 'time_video': '02m04s', 'time_video_seconds': 124}
#
# 88
# video_tree :: {'name': '88', 'time_video': '02m33s', 'time_video_seconds': 153}
#
# 83
# video_tree :: {'name': '83', 'time_video': '01m36s', 'time_video_seconds': 96}
#
# 86
# video_tree :: {'name': '86', 'time_video': '02m48s', 'time_video_seconds': 168}
#
# 92
# video_tree :: {'name': '92', 'time_video': '18m14s', 'time_video_seconds': 1094}
#
# 90
# video_tree :: {'name': '90', 'time_video': '02m33s', 'time_video_seconds': 153}
#
# 91
# video_tree :: {'name': '91', 'time_video': '01m31s', 'time_video_seconds': 91}
#
# 84
# video_tree :: {'name': '84', 'time_video': '04m28s', 'time_video_seconds': 268}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 9 - Eventos e Conferencias",
#     "number": 9,
#     "finalize_name": "09 - Eventos e Conferencias",
#     "time_module": "45m36s",
#     "time_module_seconds": 2736,
#     "number_of_videos": 10,
#     "files": [
#         {
#             "name": "83",
#             "time_video": "01m36s",
#             "time_video_seconds": 96
#         },
#         {
#             "name": "84",
#             "time_video": "04m28s",
#             "time_video_seconds": 268
#         },
#         {
#             "name": "85",
#             "time_video": "06m48s",
#             "time_video_seconds": 408
#         },
#         {
#             "name": "86",
#             "time_video": "02m48s",
#             "time_video_seconds": 168
#         },
#         {
#             "name": "87",
#             "time_video": "03m01s",
#             "time_video_seconds": 181
#         },
#         {
#             "name": "88",
#             "time_video": "02m33s",
#             "time_video_seconds": 153
#         },
#         {
#             "name": "89",
#             "time_video": "02m04s",
#             "time_video_seconds": 124
#         },
#         {
#             "name": "90",
#             "time_video": "02m33s",
#             "time_video_seconds": 153
#         },
#         {
#             "name": "91",
#             "time_video": "01m31s",
#             "time_video_seconds": 91
#         },
#         {
#             "name": "92",
#             "time_video": "18m14s",
#             "time_video_seconds": 1094
#         }
#     ]
# }
#
# ==================== 10 Network Internacional
#
# ----------- 10 - Network Internacional
# 93
# video_tree :: {'name': '93', 'time_video': '08m24s', 'time_video_seconds': 504}
#
# 94
# video_tree :: {'name': '94', 'time_video': '02m56s', 'time_video_seconds': 176}
#
# 95
# video_tree :: {'name': '95', 'time_video': '07m16s', 'time_video_seconds': 436}
#
# 96
# video_tree :: {'name': '96', 'time_video': '10m08s', 'time_video_seconds': 608}
#
#
#  => module_tree ::
# {
#     "name": "M\u00f3dulo 10 - Network Internacional",
#     "number": 10,
#     "finalize_name": "10 - Network Internacional",
#     "time_module": "28m44s",
#     "time_module_seconds": 1724,
#     "number_of_videos": 4,
#     "files": [
#         {
#             "name": "93",
#             "time_video": "08m24s",
#             "time_video_seconds": 504
#         },
#         {
#             "name": "94",
#             "time_video": "02m56s",
#             "time_video_seconds": 176
#         },
#         {
#             "name": "95",
#             "time_video": "07m16s",
#             "time_video_seconds": 436
#         },
#         {
#             "name": "96",
#             "time_video": "10m08s",
#             "time_video_seconds": 608
#         }
#     ]
# }

# %% [markdown]
# # Calcula tempo total e salva em `.json`

# %%
# itera para pegar tempo total
for el in course_tree['modules']:
    course_tree['time_course_seconds'] += el['time_module_seconds']
    course_tree['number_of_modules'] += 1

h, m, s = convert(course_tree['time_course_seconds'])
course_tree['time_course'] = get_convert(h, m, s)

# Salvar em JSON
with open('data.json', 'w') as fp:
    json.dump(course_tree, fp)

# %% [markdown]
# # Create `README-GLOBAL.md`

# %%
with open("README-GLOBAL.md",'w', encoding = 'utf-8') as f:
    f.write("# {}\n\n".format(course_tree['name_course']))
    f.write("Tempo: {} || Quantidade de Módulos {}\n\n".format(
        course_tree['time_course'], course_tree['number_of_modules'],))
    f.write("## File Tree\n\n")
    for el in course_tree['modules']:
        f.write("├─── {} ({})\n".format(el['finalize_name'], el['time_module']))
        for il in el['files']:
            f.write("│       {} ({})\n".format(il['name'], il['time_video']))
        f.write('│\n')

# %% [markdown]
# # Create individual `README.md` to each module

# %%
# Escrevendo N Modulos
for el in course_tree['modules']:
    # str(el['number']).zfill(2) + '-'
    file_module_name = el['finalize_name'] + '.md'
    with open(file_module_name, 'w', encoding = 'utf-8') as f:
        f.write("# {}\n\n".format(el['finalize_name']))
        f.write("Tempo: {} || Quantidade de Vídeos {}\n\n".format(
        el['time_module'], el['number_of_videos'],))
        for il in el['files']:
            f.write("## {} ({})\n\n\n\n".format(il['name'], il['time_video']))

# %% [markdown]
# # END
