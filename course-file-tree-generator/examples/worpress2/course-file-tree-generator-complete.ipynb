# %% [markdown]
# # course-file-tree-generator
#
#
# + Falta: Ordenar videos, por numeraçao deles e ordenar essa enumeraçao depois, pois seano fica 1, 10,22 ... 2, 20 21 , .... => isso pode ser feito passando com `.zfill(2)`
# + Separar em nome competo, nome sem numero, e numero
#
# + Mesmo que aqui a codificaço fique bugada, na saida no arquivo nao fica

# %%
import os
import json

# %%
import moviepy.editor

# %%
 # windows :: \\, linux: /
separator = '\\'

# %% [markdown]
# ## Snippets

# %%
# Converts into more readable format 
def convert(seconds):
    hours = seconds // 3600
    seconds %= 3600
    mins = seconds // 60
    seconds %= 60
    return hours, mins, seconds

# format: 00h00m00s
def get_convert(hours, mins, secs):
    if(hours == 0):
        return str(mins).zfill(2) + 'm' + str(secs).zfill(2) + 's'
    else:
        return str(hours).zfill(2) + 'h' + str(mins).zfill(2) + 'm' + str(secs).zfill(2) + 's'

# get duraction of video-file
def get_duraction_of_file(filepath):
#     video_duration = 6000
    video = moviepy.editor.VideoFileClip(filepath)
    video_duration = int(video.duration)
    hours, mins, secs = convert(video_duration)
    return get_convert(hours, mins, secs), video_duration

# %%
def list_files(dir):
    r = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            r.append(os.path.join(root, name))
    return r

# %% [markdown]
# ## Get Root

# %%
root_course = os.getcwd().split(separator)[-1]
root_course
# Out:
# 'Curso Sites Lucrativos [ WordPress, ElementorPro ]'

# %% [markdown]
# ## Get Folders

# %%
# Get all sub-folders of actual directory
path = '.'
all_directory_files_contents = os.listdir(path)

# Filter Directories Only
all_dirs = list(filter(lambda x: os.path.isdir(x), all_directory_files_contents))
all_dirs

# Remove folders invalids
list_of_exlcude_dirs = ['.ipynb_checkpoints']

for el in list_of_exlcude_dirs:
    if(el in all_dirs):
        all_dirs.remove(el)
        
# Show result
all_dirs
# Out:
# ['01 - Introdução (LEIA ANTES DE COMEÇAR)',
#  '02 - Pré Requisito',
#  '03 - Planejamento do Site',
#  '04 - Manipulação de Imagens',
#  '05 - Criando uma Landing Page',
#  '06 - Criando um Site Institucional (PARTE 1)',
#  '07 - Site Institucional (PARTE 2)',
#  '08 - Criando Um Blog',
#  '09 - Fazendo Uma Loja Virtual',
#  '10 - Criando Uma Loja Virtual (Antigo)',
#  '11 - Plugins e Ferramentas Essenciais',
#  '12 - Email Marketing',
#  '13 - S.E.O. (Otimização para o Google)',
#  '14 - Negociação',
#  '15 - Extras',
#  '16 - AULÕES DE SEXTA',
#  '17 - Elementor Pro',
#  '18 - Reuniões com Clientes (Estudos de Caso)',
#  '19 - Desenvolvendo um Site de Cliente - Passo a passo completo',
#  '20 - Análises de Sites de Alunos',
#  '21 - MENTORIAS EM GRUPO',
#  '22 - MOBILE FIRST',
#  '23 - Trabalhando de Forma Remota',
#  '24 - Site Anitta - (Efeitos de Movimento e PopUp)',
#  '25 - Teoria das Cores',
#  '26 - Como Criar um Logotipo Simples',
#  '27 - Maratona Lucrando com Sites']

# %% [markdown]
# ## Sort Folders: Dict Structure
#
# Infelizmente, vai ler na ordem, 1 => 10 => 11 ... , 2 => 20 => 21 ,... ,  e nao queremos isso. ENtâ vamos criar uma lsita de tuplas, onde cada tulpla te tamanho 3 e segue a ordem:
#
# ````
# (numero, nome-completo, nome-sem-enumeracao)
# ````
#
# **OBS:** Deverá ser alterado apra cada estrutura de pasta

# %%
def get_number_of_folder(dir_name):
    # Essa regra vai variar para cada curso
    return str(dir_name.split('-')[0]).zfill(2)

# %%
maping_sorted_dict = {}
for el in all_dirs:
    maping_sorted_dict[int(get_number_of_folder(el))] = (el, el.split('-')[1].strip()) # nome , nome se numero

maping_sorted_dict = sorted(maping_sorted_dict.items(), key=lambda x: x[0])
maping_sorted_dict
# Out:
# [(1,
#   ('01 - Introdução (LEIA ANTES DE COMEÇAR)',
#    'Introdução (LEIA ANTES DE COMEÇAR)')),
#  (2, ('02 - Pré Requisito', 'Pré Requisito')),
#  (3, ('03 - Planejamento do Site', 'Planejamento do Site')),
#  (4, ('04 - Manipulação de Imagens', 'Manipulação de Imagens')),
#  (5, ('05 - Criando uma Landing Page', 'Criando uma Landing Page')),
#  (6,
#   ('06 - Criando um Site Institucional (PARTE 1)',
#    'Criando um Site Institucional (PARTE 1)')),
#  (7, ('07 - Site Institucional (PARTE 2)', 'Site Institucional (PARTE 2)')),
#  (8, ('08 - Criando Um Blog', 'Criando Um Blog')),
#  (9, ('09 - Fazendo Uma Loja Virtual', 'Fazendo Uma Loja Virtual')),
#  (10,
#   ('10 - Criando Uma Loja Virtual (Antigo)',
#    'Criando Uma Loja Virtual (Antigo)')),
#  (11,
#   ('11 - Plugins e Ferramentas Essenciais',
#    'Plugins e Ferramentas Essenciais')),
#  (12, ('12 - Email Marketing', 'Email Marketing')),
#  (13,
#   ('13 - S.E.O. (Otimização para o Google)',
#    'S.E.O. (Otimização para o Google)')),
#  (14, ('14 - Negociação', 'Negociação')),
#  (15, ('15 - Extras', 'Extras')),
#  (16, ('16 - AULÕES DE SEXTA', 'AULÕES DE SEXTA')),
#  (17, ('17 - Elementor Pro', 'Elementor Pro')),
#  (18,
#   ('18 - Reuniões com Clientes (Estudos de Caso)',
#    'Reuniões com Clientes (Estudos de Caso)')),
#  (19,
#   ('19 - Desenvolvendo um Site de Cliente - Passo a passo completo',
#    'Desenvolvendo um Site de Cliente')),
#  (20, ('20 - Análises de Sites de Alunos', 'Análises de Sites de Alunos')),
#  (21, ('21 - MENTORIAS EM GRUPO', 'MENTORIAS EM GRUPO')),
#  (22, ('22 - MOBILE FIRST', 'MOBILE FIRST')),
#  (23, ('23 - Trabalhando de Forma Remota', 'Trabalhando de Forma Remota')),
#  (24, ('24 - Site Anitta - (Efeitos de Movimento e PopUp)', 'Site Anitta')),
#  (25, ('25 - Teoria das Cores', 'Teoria das Cores')),
#  (26,
#   ('26 - Como Criar um Logotipo Simples', 'Como Criar um Logotipo Simples')),
#  (27, ('27 - Maratona Lucrando com Sites', 'Maratona Lucrando com Sites'))]

# %% [markdown]
# ## Execute Processe - Generate Folders Structure
#
# Devo iterarra e criar uma super esttutura de ados que tera´todos os dados, e no final, eu faço o write nos arquivos, tanto no Readme quanto no repsctivo course/01-module.md
#
# curso total = tempo x
#
# ````
# {
#     name_course: root,
#     time_course: 00:00:00,
#     time_course_seconds: 0,
#     number_of_modules: 0,
#     modules: [
#         {
#             name: 'module-01-xxx',
#             number: '1',
#             time_module: 00:00:00,
#             time_module_seconds: 0,
#             number_of_videos: 0,
#             files: [
#                 {
#                     name: 'file-01'
#                     time_video: 00:00:00,
#                 },
#                 ...
#             ],
#         },
#         ...
#     ],
# }
# ````json

# %%
# Recuperando todas as pastas do curso
folders_sorted_of_course = maping_sorted_dict
folders_sorted_of_course
# Out:
# [(1,
#   ('01 - Introdução (LEIA ANTES DE COMEÇAR)',
#    'Introdução (LEIA ANTES DE COMEÇAR)')),
#  (2, ('02 - Pré Requisito', 'Pré Requisito')),
#  (3, ('03 - Planejamento do Site', 'Planejamento do Site')),
#  (4, ('04 - Manipulação de Imagens', 'Manipulação de Imagens')),
#  (5, ('05 - Criando uma Landing Page', 'Criando uma Landing Page')),
#  (6,
#   ('06 - Criando um Site Institucional (PARTE 1)',
#    'Criando um Site Institucional (PARTE 1)')),
#  (7, ('07 - Site Institucional (PARTE 2)', 'Site Institucional (PARTE 2)')),
#  (8, ('08 - Criando Um Blog', 'Criando Um Blog')),
#  (9, ('09 - Fazendo Uma Loja Virtual', 'Fazendo Uma Loja Virtual')),
#  (10,
#   ('10 - Criando Uma Loja Virtual (Antigo)',
#    'Criando Uma Loja Virtual (Antigo)')),
#  (11,
#   ('11 - Plugins e Ferramentas Essenciais',
#    'Plugins e Ferramentas Essenciais')),
#  (12, ('12 - Email Marketing', 'Email Marketing')),
#  (13,
#   ('13 - S.E.O. (Otimização para o Google)',
#    'S.E.O. (Otimização para o Google)')),
#  (14, ('14 - Negociação', 'Negociação')),
#  (15, ('15 - Extras', 'Extras')),
#  (16, ('16 - AULÕES DE SEXTA', 'AULÕES DE SEXTA')),
#  (17, ('17 - Elementor Pro', 'Elementor Pro')),
#  (18,
#   ('18 - Reuniões com Clientes (Estudos de Caso)',
#    'Reuniões com Clientes (Estudos de Caso)')),
#  (19,
#   ('19 - Desenvolvendo um Site de Cliente - Passo a passo completo',
#    'Desenvolvendo um Site de Cliente')),
#  (20, ('20 - Análises de Sites de Alunos', 'Análises de Sites de Alunos')),
#  (21, ('21 - MENTORIAS EM GRUPO', 'MENTORIAS EM GRUPO')),
#  (22, ('22 - MOBILE FIRST', 'MOBILE FIRST')),
#  (23, ('23 - Trabalhando de Forma Remota', 'Trabalhando de Forma Remota')),
#  (24, ('24 - Site Anitta - (Efeitos de Movimento e PopUp)', 'Site Anitta')),
#  (25, ('25 - Teoria das Cores', 'Teoria das Cores')),
#  (26,
#   ('26 - Como Criar um Logotipo Simples', 'Como Criar um Logotipo Simples')),
#  (27, ('27 - Maratona Lucrando com Sites', 'Maratona Lucrando com Sites'))]

# %%
# Inicializar estrutura do curso inteiro
course_tree = {
    'name_course': root_course,
    'time_course': '',
    'time_course_seconds': 0,
    'number_of_modules': 0,
    'modules' : [],
}

# Files to filter
filter_videos_files = ['mp4','ts']

# Iterar sobre as pastas do curso
# filepath_module com numero, sem numero
for number_of_module, filepath_module in folders_sorted_of_course:
    
    filepath_name, numberless_name = filepath_module[0], filepath_module[1]
    print('\n====================', number_of_module, numberless_name, '\n')
    
    # initialize module tree
    module_tree = {
        'name': filepath_name,
        'number': number_of_module,
        'finalize_name': str(number_of_module).zfill(2) + ' - ' + numberless_name,
        'time_module': '',
        'time_module_seconds': 0,
        'number_of_videos': 0,
        'files': [],
    }
    print('-----------',  str(number_of_module).zfill(2) + ' - ' + numberless_name)
    
    # Get and  Analyse videos
    video_files = list(filter(lambda x: x.split('.')[-1] in filter_videos_files, list_files(filepath_name)))
    for el in video_files:
        video_name = (os.path.splitext(el)[0]).split(separator)[-1]
        print(video_name)
        video_tree = {
            'name': '',
            'time_video': '',
            'time_video_seconds': '',
        }
        time_string, video_seconds = get_duraction_of_file(el)
        # save video data
        video_tree['time_video_seconds'] = video_seconds
        video_tree['time_video'] = time_string
        video_tree['name'] = video_name
        print('video_tree ::', video_tree, '\n')
        # save in module data
        module_tree['files'].append(video_tree)
        module_tree['number_of_videos'] += 1
        module_tree['time_module_seconds'] += video_seconds

    h, m, s = convert(module_tree['time_module_seconds'])
    module_tree['time_module'] = get_convert(h, m, s)
    
    # END
    print('\n => module_tree ::')
    print(json.dumps(module_tree, indent=4))
    course_tree['modules'].append(module_tree)
# Out:
# ==================== 1 Introdução (LEIA ANTES DE COMEÇAR)
#
# ----------- 01 - Introdução (LEIA ANTES DE COMEÇAR)
# 01 - Bem Vindo
# video_tree :: {'name': '01 - Bem Vindo', 'time_video': '08m58s', 'time_video_seconds': 538}
#
# 03 - Bônus Elementor Pro
# video_tree :: {'name': '03 - Bônus Elementor Pro', 'time_video': '04m46s', 'time_video_seconds': 286}
#
# 05 - Estrutura do Curso
# video_tree :: {'name': '05 - Estrutura do Curso', 'time_video': '01m12s', 'time_video_seconds': 72}
#
#
#  => module_tree ::
# {
#     "name": "01 - Introdu\u00e7\u00e3o (LEIA ANTES DE COME\u00c7AR)",
#     "number": 1,
#     "finalize_name": "01 - Introdu\u00e7\u00e3o (LEIA ANTES DE COME\u00c7AR)",
#     "time_module": "14m56s",
#     "time_module_seconds": 896,
#     "number_of_videos": 3,
#     "files": [
#         {
#             "name": "01 - Bem Vindo",
#             "time_video": "08m58s",
#             "time_video_seconds": 538
#         },
#         {
#             "name": "03 - B\u00f4nus Elementor Pro",
#             "time_video": "04m46s",
#             "time_video_seconds": 286
#         },
#         {
#             "name": "05 - Estrutura do Curso",
#             "time_video": "01m12s",
#             "time_video_seconds": 72
#         }
#     ]
# }
#
# ==================== 2 Pré Requisito
#
# ----------- 02 - Pré Requisito
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '01m44s', 'time_video_seconds': 104}
#
# 02 - O que é e como escolher um Domínio
# video_tree :: {'name': '02 - O que é e como escolher um Domínio', 'time_video': '07m44s', 'time_video_seconds': 464}
#
# 03 - Como contratar Hospedagem
# video_tree :: {'name': '03 - Como contratar Hospedagem', 'time_video': '08m39s', 'time_video_seconds': 519}
#
# 04 - Como Instalar o WordPress
# video_tree :: {'name': '04 - Como Instalar o WordPress', 'time_video': '17m02s', 'time_video_seconds': 1022}
#
# 05 - Instalando o Elementor
# video_tree :: {'name': '05 - Instalando o Elementor', 'time_video': '04m41s', 'time_video_seconds': 281}
#
# 06 - Instalando o Elementor Pro (Maneira Oficial)
# video_tree :: {'name': '06 - Instalando o Elementor Pro (Maneira Oficial)', 'time_video': '10m43s', 'time_video_seconds': 643}
#
# 07 - Primeiros Passos com o Elementor
# video_tree :: {'name': '07 - Primeiros Passos com o Elementor', 'time_video': '17m22s', 'time_video_seconds': 1042}
#
# 08 - Principais Elementos (Widgets) do Elementor
# video_tree :: {'name': '08 - Principais Elementos (Widgets) do Elementor', 'time_video': '06m14s', 'time_video_seconds': 374}
#
# 09 - Copiar e Colar e Colar Estilo (Dica)
# video_tree :: {'name': '09 - Copiar e Colar e Colar Estilo (Dica)', 'time_video': '02m04s', 'time_video_seconds': 124}
#
# 10 - Elementor - Navigator (Dica)
# video_tree :: {'name': '10 - Elementor - Navigator (Dica)', 'time_video': '01m05s', 'time_video_seconds': 65}
#
# 11 - Conclusão
# video_tree :: {'name': '11 - Conclusão', 'time_video': '01m02s', 'time_video_seconds': 62}
#
#
#  => module_tree ::
# {
#     "name": "02 - Pr\u00e9 Requisito",
#     "number": 2,
#     "finalize_name": "02 - Pr\u00e9 Requisito",
#     "time_module": "01h18m20s",
#     "time_module_seconds": 4700,
#     "number_of_videos": 11,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "01m44s",
#             "time_video_seconds": 104
#         },
#         {
#             "name": "02 - O que \u00e9 e como escolher um Dom\u00ednio",
#             "time_video": "07m44s",
#             "time_video_seconds": 464
#         },
#         {
#             "name": "03 - Como contratar Hospedagem",
#             "time_video": "08m39s",
#             "time_video_seconds": 519
#         },
#         {
#             "name": "04 - Como Instalar o WordPress",
#             "time_video": "17m02s",
#             "time_video_seconds": 1022
#         },
#         {
#             "name": "05 - Instalando o Elementor",
#             "time_video": "04m41s",
#             "time_video_seconds": 281
#         },
#         {
#             "name": "06 - Instalando o Elementor Pro (Maneira Oficial)",
#             "time_video": "10m43s",
#             "time_video_seconds": 643
#         },
#         {
#             "name": "07 - Primeiros Passos com o Elementor",
#             "time_video": "17m22s",
#             "time_video_seconds": 1042
#         },
#         {
#             "name": "08 - Principais Elementos (Widgets) do Elementor",
#             "time_video": "06m14s",
#             "time_video_seconds": 374
#         },
#         {
#             "name": "09 - Copiar e Colar e Colar Estilo (Dica)",
#             "time_video": "02m04s",
#             "time_video_seconds": 124
#         },
#         {
#             "name": "10 - Elementor - Navigator (Dica)",
#             "time_video": "01m05s",
#             "time_video_seconds": 65
#         },
#         {
#             "name": "11 - Conclus\u00e3o",
#             "time_video": "01m02s",
#             "time_video_seconds": 62
#         }
#     ]
# }
#
# ==================== 3 Planejamento do Site
#
# ----------- 03 - Planejamento do Site
# 01 - Qual o Propósito do seu Site (Tipos de Site)
# video_tree :: {'name': '01 - Qual o Propósito do seu Site (Tipos de Site)', 'time_video': '05m46s', 'time_video_seconds': 346}
#
# 02 - Definindo as Páginas - parte 1
# video_tree :: {'name': '02 - Definindo as Páginas - parte 1', 'time_video': '02m32s', 'time_video_seconds': 152}
#
# 02 - Definindo as Páginas - parte 2
# video_tree :: {'name': '02 - Definindo as Páginas - parte 2', 'time_video': '03m49s', 'time_video_seconds': 229}
#
# 03 - Criando Links
# video_tree :: {'name': '03 - Criando Links', 'time_video': '06m50s', 'time_video_seconds': 410}
#
# 04 - Planejamento de uma Página
# video_tree :: {'name': '04 - Planejamento de uma Página', 'time_video': '01m35s', 'time_video_seconds': 95}
#
# 05 - Referências
# video_tree :: {'name': '05 - Referências', 'time_video': '06m08s', 'time_video_seconds': 368}
#
# 06 - Brainstorm de uma Página
# video_tree :: {'name': '06 - Brainstorm de uma Página', 'time_video': '03m23s', 'time_video_seconds': 203}
#
# 07 - Dica para visualizar melhor um layout de página
# video_tree :: {'name': '07 - Dica para visualizar melhor um layout de página', 'time_video': '11m05s', 'time_video_seconds': 665}
#
# 08 - Buscando Referências na Prática
# video_tree :: {'name': '08 - Buscando Referências na Prática', 'time_video': '29m48s', 'time_video_seconds': 1788}
#
# 09 - Principais Erros de Design
# video_tree :: {'name': '09 - Principais Erros de Design', 'time_video': '12m08s', 'time_video_seconds': 728}
#
# 10 - Bônus - Templates Exclusivos
# video_tree :: {'name': '10 - Bônus - Templates Exclusivos', 'time_video': '01m15s', 'time_video_seconds': 75}
#
#
#  => module_tree ::
# {
#     "name": "03 - Planejamento do Site",
#     "number": 3,
#     "finalize_name": "03 - Planejamento do Site",
#     "time_module": "01h24m19s",
#     "time_module_seconds": 5059,
#     "number_of_videos": 11,
#     "files": [
#         {
#             "name": "01 - Qual o Prop\u00f3sito do seu Site (Tipos de Site)",
#             "time_video": "05m46s",
#             "time_video_seconds": 346
#         },
#         {
#             "name": "02 - Definindo as P\u00e1ginas - parte 1",
#             "time_video": "02m32s",
#             "time_video_seconds": 152
#         },
#         {
#             "name": "02 - Definindo as P\u00e1ginas - parte 2",
#             "time_video": "03m49s",
#             "time_video_seconds": 229
#         },
#         {
#             "name": "03 - Criando Links",
#             "time_video": "06m50s",
#             "time_video_seconds": 410
#         },
#         {
#             "name": "04 - Planejamento de uma P\u00e1gina",
#             "time_video": "01m35s",
#             "time_video_seconds": 95
#         },
#         {
#             "name": "05 - Refer\u00eancias",
#             "time_video": "06m08s",
#             "time_video_seconds": 368
#         },
#         {
#             "name": "06 - Brainstorm de uma P\u00e1gina",
#             "time_video": "03m23s",
#             "time_video_seconds": 203
#         },
#         {
#             "name": "07 - Dica para visualizar melhor um layout de p\u00e1gina",
#             "time_video": "11m05s",
#             "time_video_seconds": 665
#         },
#         {
#             "name": "08 - Buscando Refer\u00eancias na Pr\u00e1tica",
#             "time_video": "29m48s",
#             "time_video_seconds": 1788
#         },
#         {
#             "name": "09 - Principais Erros de Design",
#             "time_video": "12m08s",
#             "time_video_seconds": 728
#         },
#         {
#             "name": "10 - B\u00f4nus - Templates Exclusivos",
#             "time_video": "01m15s",
#             "time_video_seconds": 75
#         }
#     ]
# }
#
# ==================== 4 Manipulação de Imagens
#
# ----------- 04 - Manipulação de Imagens
# 01 - Introdução Manipulação de Imagens
# video_tree :: {'name': '01 - Introdução Manipulação de Imagens', 'time_video': '00m20s', 'time_video_seconds': 20}
#
# 02 - Tamanhos e Resoluções
# video_tree :: {'name': '02 - Tamanhos e Resoluções', 'time_video': '07m26s', 'time_video_seconds': 446}
#
# 03 - Como ver a Resolução da Imagem
# video_tree :: {'name': '03 - Como ver a Resolução da Imagem', 'time_video': '01m07s', 'time_video_seconds': 67}
#
# 04 - Formatos de Imagens para Web
# video_tree :: {'name': '04 - Formatos de Imagens para Web', 'time_video': '08m11s', 'time_video_seconds': 491}
#
# 05 - Como ver o Formato de uma Imagem
# video_tree :: {'name': '05 - Como ver o Formato de uma Imagem', 'time_video': '02m01s', 'time_video_seconds': 121}
#
# 06 - Bancos de Imagens
# video_tree :: {'name': '06 - Bancos de Imagens', 'time_video': '04m49s', 'time_video_seconds': 289}
#
# 07 - Photoshop e Photopea
# video_tree :: {'name': '07 - Photoshop e Photopea', 'time_video': '04m36s', 'time_video_seconds': 276}
#
# 08 - Primeiras Impressões Photopea
# video_tree :: {'name': '08 - Primeiras Impressões Photopea', 'time_video': '05m28s', 'time_video_seconds': 328}
#
# 09 - Optimizadores de Imagem
# video_tree :: {'name': '09 - Optimizadores de Imagem', 'time_video': '07m00s', 'time_video_seconds': 420}
#
# 10 - Como Remover o Fundo de Uma Imagem com a varinha mágica
# video_tree :: {'name': '10 - Como Remover o Fundo de Uma Imagem com a varinha mágica', 'time_video': '01m25s', 'time_video_seconds': 85}
#
# 10 - Como Remover o Fundo de Uma Imagem
# video_tree :: {'name': '10 - Como Remover o Fundo de Uma Imagem', 'time_video': '04m09s', 'time_video_seconds': 249}
#
# 11 - Como Cortar uma Imagem
# video_tree :: {'name': '11 - Como Cortar uma Imagem', 'time_video': '03m20s', 'time_video_seconds': 200}
#
#
#  => module_tree ::
# {
#     "name": "04 - Manipula\u00e7\u00e3o de Imagens",
#     "number": 4,
#     "finalize_name": "04 - Manipula\u00e7\u00e3o de Imagens",
#     "time_module": "49m52s",
#     "time_module_seconds": 2992,
#     "number_of_videos": 12,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o Manipula\u00e7\u00e3o de Imagens",
#             "time_video": "00m20s",
#             "time_video_seconds": 20
#         },
#         {
#             "name": "02 - Tamanhos e Resolu\u00e7\u00f5es",
#             "time_video": "07m26s",
#             "time_video_seconds": 446
#         },
#         {
#             "name": "03 - Como ver a Resolu\u00e7\u00e3o da Imagem",
#             "time_video": "01m07s",
#             "time_video_seconds": 67
#         },
#         {
#             "name": "04 - Formatos de Imagens para Web",
#             "time_video": "08m11s",
#             "time_video_seconds": 491
#         },
#         {
#             "name": "05 - Como ver o Formato de uma Imagem",
#             "time_video": "02m01s",
#             "time_video_seconds": 121
#         },
#         {
#             "name": "06 - Bancos de Imagens",
#             "time_video": "04m49s",
#             "time_video_seconds": 289
#         },
#         {
#             "name": "07 - Photoshop e Photopea",
#             "time_video": "04m36s",
#             "time_video_seconds": 276
#         },
#         {
#             "name": "08 - Primeiras Impress\u00f5es Photopea",
#             "time_video": "05m28s",
#             "time_video_seconds": 328
#         },
#         {
#             "name": "09 - Optimizadores de Imagem",
#             "time_video": "07m00s",
#             "time_video_seconds": 420
#         },
#         {
#             "name": "10 - Como Remover o Fundo de Uma Imagem com a varinha m\u00e1gica",
#             "time_video": "01m25s",
#             "time_video_seconds": 85
#         },
#         {
#             "name": "10 - Como Remover o Fundo de Uma Imagem",
#             "time_video": "04m09s",
#             "time_video_seconds": 249
#         },
#         {
#             "name": "11 - Como Cortar uma Imagem",
#             "time_video": "03m20s",
#             "time_video_seconds": 200
#         }
#     ]
# }
#
# ==================== 5 Criando uma Landing Page
#
# ----------- 05 - Criando uma Landing Page
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '04m57s', 'time_video_seconds': 297}
#
# 02 - Configurações Iniciais
# video_tree :: {'name': '02 - Configurações Iniciais', 'time_video': '05m25s', 'time_video_seconds': 325}
#
# 03 - Capa - parte 1
# video_tree :: {'name': '03 - Capa - parte 1', 'time_video': '28m26s', 'time_video_seconds': 1706}
#
# 03 - Capa - parte 2
# video_tree :: {'name': '03 - Capa - parte 2', 'time_video': '05m09s', 'time_video_seconds': 309}
#
# 04 - Seção de Informações
# video_tree :: {'name': '04 - Seção de Informações', 'time_video': '18m04s', 'time_video_seconds': 1084}
#
# 05 - Seção de Testemunhos
# video_tree :: {'name': '05 - Seção de Testemunhos', 'time_video': '20m23s', 'time_video_seconds': 1223}
#
# 06 - Seção de Dados
# video_tree :: {'name': '06 - Seção de Dados', 'time_video': '10m38s', 'time_video_seconds': 638}
#
# 07 - Footer
# video_tree :: {'name': '07 - Footer', 'time_video': '09m36s', 'time_video_seconds': 576}
#
# 08 - Otimizações para Celular
# video_tree :: {'name': '08 - Otimizações para Celular', 'time_video': '07m42s', 'time_video_seconds': 462}
#
# 09 - Exportando a Página para Outros Projetos
# video_tree :: {'name': '09 - Exportando a Página para Outros Projetos', 'time_video': '06m43s', 'time_video_seconds': 403}
#
# 10 - Print da Página (Dica Extra)
# video_tree :: {'name': '10 - Print da Página (Dica Extra)', 'time_video': '04m12s', 'time_video_seconds': 252}
#
#
#  => module_tree ::
# {
#     "name": "05 - Criando uma Landing Page",
#     "number": 5,
#     "finalize_name": "05 - Criando uma Landing Page",
#     "time_module": "02h01m15s",
#     "time_module_seconds": 7275,
#     "number_of_videos": 11,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "04m57s",
#             "time_video_seconds": 297
#         },
#         {
#             "name": "02 - Configura\u00e7\u00f5es Iniciais",
#             "time_video": "05m25s",
#             "time_video_seconds": 325
#         },
#         {
#             "name": "03 - Capa - parte 1",
#             "time_video": "28m26s",
#             "time_video_seconds": 1706
#         },
#         {
#             "name": "03 - Capa - parte 2",
#             "time_video": "05m09s",
#             "time_video_seconds": 309
#         },
#         {
#             "name": "04 - Se\u00e7\u00e3o de Informa\u00e7\u00f5es",
#             "time_video": "18m04s",
#             "time_video_seconds": 1084
#         },
#         {
#             "name": "05 - Se\u00e7\u00e3o de Testemunhos",
#             "time_video": "20m23s",
#             "time_video_seconds": 1223
#         },
#         {
#             "name": "06 - Se\u00e7\u00e3o de Dados",
#             "time_video": "10m38s",
#             "time_video_seconds": 638
#         },
#         {
#             "name": "07 - Footer",
#             "time_video": "09m36s",
#             "time_video_seconds": 576
#         },
#         {
#             "name": "08 - Otimiza\u00e7\u00f5es para Celular",
#             "time_video": "07m42s",
#             "time_video_seconds": 462
#         },
#         {
#             "name": "09 - Exportando a P\u00e1gina para Outros Projetos",
#             "time_video": "06m43s",
#             "time_video_seconds": 403
#         },
#         {
#             "name": "10 - Print da P\u00e1gina (Dica Extra)",
#             "time_video": "04m12s",
#             "time_video_seconds": 252
#         }
#     ]
# }
#
# ==================== 6 Criando um Site Institucional (PARTE 1)
#
# ----------- 06 - Criando um Site Institucional (PARTE 1)
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '03m32s', 'time_video_seconds': 212}
#
# 02 - PARTE 1 - Modelos Prontos -----
# video_tree :: {'name': '02 - PARTE 1 - Modelos Prontos -----', 'time_video': '03m04s', 'time_video_seconds': 184}
#
# 03 - Configurações iniciais Necessárias
# video_tree :: {'name': '03 - Configurações iniciais Necessárias', 'time_video': '03m17s', 'time_video_seconds': 197}
#
# 04 - Instalando o Astra e Escolhendo um Modelo
# video_tree :: {'name': '04 - Instalando o Astra e Escolhendo um Modelo', 'time_video': '07m56s', 'time_video_seconds': 476}
#
# 05 - O que mudou após a importação do modelo - parte 1
# video_tree :: {'name': '05 - O que mudou após a importação do modelo - parte 1', 'time_video': '07m19s', 'time_video_seconds': 439}
#
# 05 - O que mudou após a importação do modelo - parte 2
# video_tree :: {'name': '05 - O que mudou após a importação do modelo - parte 2', 'time_video': '02m33s', 'time_video_seconds': 153}
#
# 06 - Editando a Página
# video_tree :: {'name': '06 - Editando a Página', 'time_video': '06m18s', 'time_video_seconds': 378}
#
# 07 - Editando o Tema
# video_tree :: {'name': '07 - Editando o Tema', 'time_video': '15m31s', 'time_video_seconds': 931}
#
# 08 - Editando o Menu
# video_tree :: {'name': '08 - Editando o Menu', 'time_video': '08m28s', 'time_video_seconds': 508}
#
# 09 - Editando as Páginas com o Elementor (Cores)
# video_tree :: {'name': '09 - Editando as Páginas com o Elementor (Cores)', 'time_video': '13m43s', 'time_video_seconds': 823}
#
# 10 - Editando as Páginas com o Elementor (Imagens) - parte 1
# video_tree :: {'name': '10 - Editando as Páginas com o Elementor (Imagens) - parte 1', 'time_video': '07m02s', 'time_video_seconds': 422}
#
# 10 - Editando as Páginas com o Elementor (Imagens) - parte 2
# video_tree :: {'name': '10 - Editando as Páginas com o Elementor (Imagens) - parte 2', 'time_video': '09m25s', 'time_video_seconds': 565}
#
# 11 - Editando as Páginas com o Elementor (Textos)
# video_tree :: {'name': '11 - Editando as Páginas com o Elementor (Textos)', 'time_video': '07m42s', 'time_video_seconds': 462}
#
# 12 - Adicionando Novas Seções
# video_tree :: {'name': '12 - Adicionando Novas Seções', 'time_video': '12m20s', 'time_video_seconds': 740}
#
# 13 - Otimizações para Celular
# video_tree :: {'name': '13 - Otimizações para Celular', 'time_video': '12m07s', 'time_video_seconds': 727}
#
# 14 - Padronizando as Páginas - parte 1
# video_tree :: {'name': '14 - Padronizando as Páginas - parte 1', 'time_video': '09m06s', 'time_video_seconds': 546}
#
# 14 - Padronizando as Páginas - parte 2
# video_tree :: {'name': '14 - Padronizando as Páginas - parte 2', 'time_video': '06m43s', 'time_video_seconds': 403}
#
# 15 - Footer, Global Widget e Seções Globais - parte 1
# video_tree :: {'name': '15 - Footer, Global Widget e Seções Globais - parte 1', 'time_video': '14m27s', 'time_video_seconds': 867}
#
# 15 - Footer, Global Widget e Seções Globais - parte 2
# video_tree :: {'name': '15 - Footer, Global Widget e Seções Globais - parte 2', 'time_video': '07m09s', 'time_video_seconds': 429}
#
# 15 - Footer, Global Widget e Seções Globais - parte 3
# video_tree :: {'name': '15 - Footer, Global Widget e Seções Globais - parte 3', 'time_video': '07m17s', 'time_video_seconds': 437}
#
# 16 - Adicionando o Feed do Instagram e Outros Plugins - parte 1
# video_tree :: {'name': '16 - Adicionando o Feed do Instagram e Outros Plugins - parte 1', 'time_video': '08m47s', 'time_video_seconds': 527}
#
# 16 - Adicionando o Feed do Instagram e Outros Plugins - parte 2
# video_tree :: {'name': '16 - Adicionando o Feed do Instagram e Outros Plugins - parte 2', 'time_video': '03m54s', 'time_video_seconds': 234}
#
# 17 - Conclusão Parte 1
# video_tree :: {'name': '17 - Conclusão Parte 1', 'time_video': '03m23s', 'time_video_seconds': 203}
#
#
#  => module_tree ::
# {
#     "name": "06 - Criando um Site Institucional (PARTE 1)",
#     "number": 6,
#     "finalize_name": "06 - Criando um Site Institucional (PARTE 1)",
#     "time_module": "03h01m03s",
#     "time_module_seconds": 10863,
#     "number_of_videos": 23,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "03m32s",
#             "time_video_seconds": 212
#         },
#         {
#             "name": "02 - PARTE 1 - Modelos Prontos -----",
#             "time_video": "03m04s",
#             "time_video_seconds": 184
#         },
#         {
#             "name": "03 - Configura\u00e7\u00f5es iniciais Necess\u00e1rias",
#             "time_video": "03m17s",
#             "time_video_seconds": 197
#         },
#         {
#             "name": "04 - Instalando o Astra e Escolhendo um Modelo",
#             "time_video": "07m56s",
#             "time_video_seconds": 476
#         },
#         {
#             "name": "05 - O que mudou ap\u00f3s a importa\u00e7\u00e3o do modelo - parte 1",
#             "time_video": "07m19s",
#             "time_video_seconds": 439
#         },
#         {
#             "name": "05 - O que mudou ap\u00f3s a importa\u00e7\u00e3o do modelo - parte 2",
#             "time_video": "02m33s",
#             "time_video_seconds": 153
#         },
#         {
#             "name": "06 - Editando a P\u00e1gina",
#             "time_video": "06m18s",
#             "time_video_seconds": 378
#         },
#         {
#             "name": "07 - Editando o Tema",
#             "time_video": "15m31s",
#             "time_video_seconds": 931
#         },
#         {
#             "name": "08 - Editando o Menu",
#             "time_video": "08m28s",
#             "time_video_seconds": 508
#         },
#         {
#             "name": "09 - Editando as P\u00e1ginas com o Elementor (Cores)",
#             "time_video": "13m43s",
#             "time_video_seconds": 823
#         },
#         {
#             "name": "10 - Editando as P\u00e1ginas com o Elementor (Imagens) - parte 1",
#             "time_video": "07m02s",
#             "time_video_seconds": 422
#         },
#         {
#             "name": "10 - Editando as P\u00e1ginas com o Elementor (Imagens) - parte 2",
#             "time_video": "09m25s",
#             "time_video_seconds": 565
#         },
#         {
#             "name": "11 - Editando as P\u00e1ginas com o Elementor (Textos)",
#             "time_video": "07m42s",
#             "time_video_seconds": 462
#         },
#         {
#             "name": "12 - Adicionando Novas Se\u00e7\u00f5es",
#             "time_video": "12m20s",
#             "time_video_seconds": 740
#         },
#         {
#             "name": "13 - Otimiza\u00e7\u00f5es para Celular",
#             "time_video": "12m07s",
#             "time_video_seconds": 727
#         },
#         {
#             "name": "14 - Padronizando as P\u00e1ginas - parte 1",
#             "time_video": "09m06s",
#             "time_video_seconds": 546
#         },
#         {
#             "name": "14 - Padronizando as P\u00e1ginas - parte 2",
#             "time_video": "06m43s",
#             "time_video_seconds": 403
#         },
#         {
#             "name": "15 - Footer, Global Widget e Se\u00e7\u00f5es Globais - parte 1",
#             "time_video": "14m27s",
#             "time_video_seconds": 867
#         },
#         {
#             "name": "15 - Footer, Global Widget e Se\u00e7\u00f5es Globais - parte 2",
#             "time_video": "07m09s",
#             "time_video_seconds": 429
#         },
#         {
#             "name": "15 - Footer, Global Widget e Se\u00e7\u00f5es Globais - parte 3",
#             "time_video": "07m17s",
#             "time_video_seconds": 437
#         },
#         {
#             "name": "16 - Adicionando o Feed do Instagram e Outros Plugins - parte 1",
#             "time_video": "08m47s",
#             "time_video_seconds": 527
#         },
#         {
#             "name": "16 - Adicionando o Feed do Instagram e Outros Plugins - parte 2",
#             "time_video": "03m54s",
#             "time_video_seconds": 234
#         },
#         {
#             "name": "17 - Conclus\u00e3o Parte 1",
#             "time_video": "03m23s",
#             "time_video_seconds": 203
#         }
#     ]
# }
#
# ==================== 7 Site Institucional (PARTE 2)
#
# ----------- 07 - Site Institucional (PARTE 2)
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '04m24s', 'time_video_seconds': 264}
#
# 02 - Referência e Planejamento - parte 1
# video_tree :: {'name': '02 - Referência e Planejamento - parte 1', 'time_video': '06m45s', 'time_video_seconds': 405}
#
# 02 - Referência e Planejamento - parte 2
# video_tree :: {'name': '02 - Referência e Planejamento - parte 2', 'time_video': '04m09s', 'time_video_seconds': 249}
#
# 03 - Configurações Importantes
# video_tree :: {'name': '03 - Configurações Importantes', 'time_video': '04m08s', 'time_video_seconds': 248}
#
# 04 - Página Inicial (Menu, Capa e Serviços) - parte 1
# video_tree :: {'name': '04 - Página Inicial (Menu, Capa e Serviços) - parte 1', 'time_video': '16m48s', 'time_video_seconds': 1008}
#
# 04 - Página Inicial (Menu, Capa e Serviços) - parte 2
# video_tree :: {'name': '04 - Página Inicial (Menu, Capa e Serviços) - parte 2', 'time_video': '17m49s', 'time_video_seconds': 1069}
#
# 04 - Página Inicial (Menu, Capa e Serviços) - parte 3
# video_tree :: {'name': '04 - Página Inicial (Menu, Capa e Serviços) - parte 3', 'time_video': '19m21s', 'time_video_seconds': 1161}
#
# 05 - Página Inicial (CTA, Descrição e Clientes) - parte 1
# video_tree :: {'name': '05 - Página Inicial (CTA, Descrição e Clientes) - parte 1', 'time_video': '09m27s', 'time_video_seconds': 567}
#
# 05 - Página Inicial (CTA, Descrição e Clientes) - parte 2
# video_tree :: {'name': '05 - Página Inicial (CTA, Descrição e Clientes) - parte 2', 'time_video': '06m28s', 'time_video_seconds': 388}
#
# 05 - Página Inicial (CTA, Descrição e Clientes) - parte 3
# video_tree :: {'name': '05 - Página Inicial (CTA, Descrição e Clientes) - parte 3', 'time_video': '06m11s', 'time_video_seconds': 371}
#
# 06 - Página Inicial (CTA, Formulário e Footer) - parte 1
# video_tree :: {'name': '06 - Página Inicial (CTA, Formulário e Footer) - parte 1', 'time_video': '06m57s', 'time_video_seconds': 417}
#
# 06 - Página Inicial (CTA, Formulário e Footer) - parte 2
# video_tree :: {'name': '06 - Página Inicial (CTA, Formulário e Footer) - parte 2', 'time_video': '11m41s', 'time_video_seconds': 701}
#
# 06 - Página Inicial (CTA, Formulário e Footer) - parte 3
# video_tree :: {'name': '06 - Página Inicial (CTA, Formulário e Footer) - parte 3', 'time_video': '09m24s', 'time_video_seconds': 564}
#
# 07 - Otimizando para Celular
# video_tree :: {'name': '07 - Otimizando para Celular', 'time_video': '12m55s', 'time_video_seconds': 775}
#
# 08 - Animações e Efeitos de Movimento
# video_tree :: {'name': '08 - Animações e Efeitos de Movimento', 'time_video': '08m09s', 'time_video_seconds': 489}
#
# 09 - Padronizando Menu e Footer
# video_tree :: {'name': '09 - Padronizando Menu e Footer', 'time_video': '11m07s', 'time_video_seconds': 667}
#
# 10 - Página de Contato - parte 1
# video_tree :: {'name': '10 - Página de Contato - parte 1', 'time_video': '03m45s', 'time_video_seconds': 225}
#
# 10 - Página de Contato - parte 2
# video_tree :: {'name': '10 - Página de Contato - parte 2', 'time_video': '06m51s', 'time_video_seconds': 411}
#
# 10 - Página de Contato - parte 3
# video_tree :: {'name': '10 - Página de Contato - parte 3', 'time_video': '04m16s', 'time_video_seconds': 256}
#
# 11 - Página Sobre Nós
# video_tree :: {'name': '11 - Página Sobre Nós', 'time_video': '06m13s', 'time_video_seconds': 373}
#
# 12 - Definindo a página inicial e finalização
# video_tree :: {'name': '12 - Definindo a página inicial e finalização', 'time_video': '03m41s', 'time_video_seconds': 221}
#
#
#  => module_tree ::
# {
#     "name": "07 - Site Institucional (PARTE 2)",
#     "number": 7,
#     "finalize_name": "07 - Site Institucional (PARTE 2)",
#     "time_module": "03h00m29s",
#     "time_module_seconds": 10829,
#     "number_of_videos": 21,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "04m24s",
#             "time_video_seconds": 264
#         },
#         {
#             "name": "02 - Refer\u00eancia e Planejamento - parte 1",
#             "time_video": "06m45s",
#             "time_video_seconds": 405
#         },
#         {
#             "name": "02 - Refer\u00eancia e Planejamento - parte 2",
#             "time_video": "04m09s",
#             "time_video_seconds": 249
#         },
#         {
#             "name": "03 - Configura\u00e7\u00f5es Importantes",
#             "time_video": "04m08s",
#             "time_video_seconds": 248
#         },
#         {
#             "name": "04 - P\u00e1gina Inicial (Menu, Capa e Servi\u00e7os) - parte 1",
#             "time_video": "16m48s",
#             "time_video_seconds": 1008
#         },
#         {
#             "name": "04 - P\u00e1gina Inicial (Menu, Capa e Servi\u00e7os) - parte 2",
#             "time_video": "17m49s",
#             "time_video_seconds": 1069
#         },
#         {
#             "name": "04 - P\u00e1gina Inicial (Menu, Capa e Servi\u00e7os) - parte 3",
#             "time_video": "19m21s",
#             "time_video_seconds": 1161
#         },
#         {
#             "name": "05 - P\u00e1gina Inicial (CTA, Descri\u00e7\u00e3o e Clientes) - parte 1",
#             "time_video": "09m27s",
#             "time_video_seconds": 567
#         },
#         {
#             "name": "05 - P\u00e1gina Inicial (CTA, Descri\u00e7\u00e3o e Clientes) - parte 2",
#             "time_video": "06m28s",
#             "time_video_seconds": 388
#         },
#         {
#             "name": "05 - P\u00e1gina Inicial (CTA, Descri\u00e7\u00e3o e Clientes) - parte 3",
#             "time_video": "06m11s",
#             "time_video_seconds": 371
#         },
#         {
#             "name": "06 - P\u00e1gina Inicial (CTA, Formul\u00e1rio e Footer) - parte 1",
#             "time_video": "06m57s",
#             "time_video_seconds": 417
#         },
#         {
#             "name": "06 - P\u00e1gina Inicial (CTA, Formul\u00e1rio e Footer) - parte 2",
#             "time_video": "11m41s",
#             "time_video_seconds": 701
#         },
#         {
#             "name": "06 - P\u00e1gina Inicial (CTA, Formul\u00e1rio e Footer) - parte 3",
#             "time_video": "09m24s",
#             "time_video_seconds": 564
#         },
#         {
#             "name": "07 - Otimizando para Celular",
#             "time_video": "12m55s",
#             "time_video_seconds": 775
#         },
#         {
#             "name": "08 - Anima\u00e7\u00f5es e Efeitos de Movimento",
#             "time_video": "08m09s",
#             "time_video_seconds": 489
#         },
#         {
#             "name": "09 - Padronizando Menu e Footer",
#             "time_video": "11m07s",
#             "time_video_seconds": 667
#         },
#         {
#             "name": "10 - P\u00e1gina de Contato - parte 1",
#             "time_video": "03m45s",
#             "time_video_seconds": 225
#         },
#         {
#             "name": "10 - P\u00e1gina de Contato - parte 2",
#             "time_video": "06m51s",
#             "time_video_seconds": 411
#         },
#         {
#             "name": "10 - P\u00e1gina de Contato - parte 3",
#             "time_video": "04m16s",
#             "time_video_seconds": 256
#         },
#         {
#             "name": "11 - P\u00e1gina Sobre N\u00f3s",
#             "time_video": "06m13s",
#             "time_video_seconds": 373
#         },
#         {
#             "name": "12 - Definindo a p\u00e1gina inicial e finaliza\u00e7\u00e3o",
#             "time_video": "03m41s",
#             "time_video_seconds": 221
#         }
#     ]
# }
#
# ==================== 8 Criando Um Blog
#
# ----------- 08 - Criando Um Blog
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '02m47s', 'time_video_seconds': 167}
#
# 02 - Pra que serve um Blog
# video_tree :: {'name': '02 - Pra que serve um Blog', 'time_video': '05m23s', 'time_video_seconds': 323}
#
# 03 - Buscando Referências
# video_tree :: {'name': '03 - Buscando Referências', 'time_video': '08m30s', 'time_video_seconds': 510}
#
# 04 - Criando Seu Primeiro Post
# video_tree :: {'name': '04 - Criando Seu Primeiro Post', 'time_video': '08m02s', 'time_video_seconds': 482}
#
# 05 - Estruturas de Blog no WordPress
# video_tree :: {'name': '05 - Estruturas de Blog no WordPress', 'time_video': '04m10s', 'time_video_seconds': 250}
#
# 06 - Criando o Modelo da Página de Posts - parte 1
# video_tree :: {'name': '06 - Criando o Modelo da Página de Posts - parte 1', 'time_video': '12m26s', 'time_video_seconds': 746}
#
# 06 - Criando o Modelo da Página de Posts - parte 2
# video_tree :: {'name': '06 - Criando o Modelo da Página de Posts - parte 2', 'time_video': '17m38s', 'time_video_seconds': 1058}
#
# 06 - Criando o Modelo da Página de Posts - parte 3
# video_tree :: {'name': '06 - Criando o Modelo da Página de Posts - parte 3', 'time_video': '14m13s', 'time_video_seconds': 853}
#
# 07 - Escrevendo Boas Postagens
# video_tree :: {'name': '07 - Escrevendo Boas Postagens', 'time_video': '11m39s', 'time_video_seconds': 699}
#
# 08 - Categorias
# video_tree :: {'name': '08 - Categorias', 'time_video': '07m30s', 'time_video_seconds': 450}
#
# 09 - Criando a Página Blog
# video_tree :: {'name': '09 - Criando a Página Blog', 'time_video': '07m53s', 'time_video_seconds': 473}
#
# 10 - Usando o Widget de Posts - parte 1
# video_tree :: {'name': '10 - Usando o Widget de Posts - parte 1', 'time_video': '14m31s', 'time_video_seconds': 871}
#
# 10 - Usando o Widget de Posts - parte 2
# video_tree :: {'name': '10 - Usando o Widget de Posts - parte 2', 'time_video': '11m15s', 'time_video_seconds': 675}
#
# 11 - Finalizando o Layout da Página de Posts
# video_tree :: {'name': '11 - Finalizando o Layout da Página de Posts', 'time_video': '10m09s', 'time_video_seconds': 609}
#
# 12 - (Extra) Como trocar a foto de perfil do Usuário - Gravatar
# video_tree :: {'name': '12 - (Extra) Como trocar a foto de perfil do Usuário - Gravatar', 'time_video': '04m58s', 'time_video_seconds': 298}
#
#
#  => module_tree ::
# {
#     "name": "08 - Criando Um Blog",
#     "number": 8,
#     "finalize_name": "08 - Criando Um Blog",
#     "time_module": "02h21m04s",
#     "time_module_seconds": 8464,
#     "number_of_videos": 15,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "02m47s",
#             "time_video_seconds": 167
#         },
#         {
#             "name": "02 - Pra que serve um Blog",
#             "time_video": "05m23s",
#             "time_video_seconds": 323
#         },
#         {
#             "name": "03 - Buscando Refer\u00eancias",
#             "time_video": "08m30s",
#             "time_video_seconds": 510
#         },
#         {
#             "name": "04 - Criando Seu Primeiro Post",
#             "time_video": "08m02s",
#             "time_video_seconds": 482
#         },
#         {
#             "name": "05 - Estruturas de Blog no WordPress",
#             "time_video": "04m10s",
#             "time_video_seconds": 250
#         },
#         {
#             "name": "06 - Criando o Modelo da P\u00e1gina de Posts - parte 1",
#             "time_video": "12m26s",
#             "time_video_seconds": 746
#         },
#         {
#             "name": "06 - Criando o Modelo da P\u00e1gina de Posts - parte 2",
#             "time_video": "17m38s",
#             "time_video_seconds": 1058
#         },
#         {
#             "name": "06 - Criando o Modelo da P\u00e1gina de Posts - parte 3",
#             "time_video": "14m13s",
#             "time_video_seconds": 853
#         },
#         {
#             "name": "07 - Escrevendo Boas Postagens",
#             "time_video": "11m39s",
#             "time_video_seconds": 699
#         },
#         {
#             "name": "08 - Categorias",
#             "time_video": "07m30s",
#             "time_video_seconds": 450
#         },
#         {
#             "name": "09 - Criando a P\u00e1gina Blog",
#             "time_video": "07m53s",
#             "time_video_seconds": 473
#         },
#         {
#             "name": "10 - Usando o Widget de Posts - parte 1",
#             "time_video": "14m31s",
#             "time_video_seconds": 871
#         },
#         {
#             "name": "10 - Usando o Widget de Posts - parte 2",
#             "time_video": "11m15s",
#             "time_video_seconds": 675
#         },
#         {
#             "name": "11 - Finalizando o Layout da P\u00e1gina de Posts",
#             "time_video": "10m09s",
#             "time_video_seconds": 609
#         },
#         {
#             "name": "12 - (Extra) Como trocar a foto de perfil do Usu\u00e1rio - Gravatar",
#             "time_video": "04m58s",
#             "time_video_seconds": 298
#         }
#     ]
# }
#
# ==================== 9 Fazendo Uma Loja Virtual
#
# ----------- 09 - Fazendo Uma Loja Virtual
# 01 - Passos Iniciais e Conceitos Basicos - parte 1
# video_tree :: {'name': '01 - Passos Iniciais e Conceitos Basicos - parte 1', 'time_video': '01m09s', 'time_video_seconds': 69}
#
# 01 - Passos Iniciais e Conceitos Basicos - parte 2
# video_tree :: {'name': '01 - Passos Iniciais e Conceitos Basicos - parte 2', 'time_video': '03m18s', 'time_video_seconds': 198}
#
# 02 - Planejando o Seu Ecommerce
# video_tree :: {'name': '02 - Planejando o Seu Ecommerce', 'time_video': '08m47s', 'time_video_seconds': 527}
#
# 03 - Loja de Informatica (Astra) - parte 1 - P1
# video_tree :: {'name': '03 - Loja de Informatica (Astra) - parte 1 - P1', 'time_video': '01m33s', 'time_video_seconds': 93}
#
# 03 - Loja de Informatica (Astra) - parte 2 - P1
# video_tree :: {'name': '03 - Loja de Informatica (Astra) - parte 2 - P1', 'time_video': '05m16s', 'time_video_seconds': 316}
#
# 03 - Loja de Informatica (Astra) - parte 3 - P1
# video_tree :: {'name': '03 - Loja de Informatica (Astra) - parte 3 - P1', 'time_video': '02m54s', 'time_video_seconds': 174}
#
# 04 - Loja de Informatica (Astra) - parte 1 - P2
# video_tree :: {'name': '04 - Loja de Informatica (Astra) - parte 1 - P2', 'time_video': '18m02s', 'time_video_seconds': 1082}
#
# 04 - Loja de Informatica (Astra) - parte 2 - P2
# video_tree :: {'name': '04 - Loja de Informatica (Astra) - parte 2 - P2', 'time_video': '24m40s', 'time_video_seconds': 1480}
#
# 05 - Paginas da Loja de Informatica (Astra) - parte 1 - P3
# video_tree :: {'name': '05 - Paginas da Loja de Informatica (Astra) - parte 1 - P3', 'time_video': '20m58s', 'time_video_seconds': 1258}
#
# 05 - Paginas da Loja de Informatica (Astra) - parte 2 - P3
# video_tree :: {'name': '05 - Paginas da Loja de Informatica (Astra) - parte 2 - P3', 'time_video': '10m41s', 'time_video_seconds': 641}
#
# 05 - Paginas da Loja de Informatica (Astra) - parte 3 - P3
# video_tree :: {'name': '05 - Paginas da Loja de Informatica (Astra) - parte 3 - P3', 'time_video': '08m12s', 'time_video_seconds': 492}
#
# 06 - Loja de Informatica (Astra) - parte 1 - P4
# video_tree :: {'name': '06 - Loja de Informatica (Astra) - parte 1 - P4', 'time_video': '15m00s', 'time_video_seconds': 900}
#
# 06 - Loja de Informatica (Astra) - parte 2 - P4
# video_tree :: {'name': '06 - Loja de Informatica (Astra) - parte 2 - P4', 'time_video': '21m52s', 'time_video_seconds': 1312}
#
# 06 - Loja de Informatica (Astra) - parte 3 - P4
# video_tree :: {'name': '06 - Loja de Informatica (Astra) - parte 3 - P4', 'time_video': '19m27s', 'time_video_seconds': 1167}
#
# 07 - Loja de Informatica (Astra) - parte 1 - P5
# video_tree :: {'name': '07 - Loja de Informatica (Astra) - parte 1 - P5', 'time_video': '06m25s', 'time_video_seconds': 385}
#
# 07 - Loja de Informatica (Astra) - parte 2 - P5
# video_tree :: {'name': '07 - Loja de Informatica (Astra) - parte 2 - P5', 'time_video': '05m56s', 'time_video_seconds': 356}
#
# 07 - Loja de Informatica (Astra) - parte 3 - P5
# video_tree :: {'name': '07 - Loja de Informatica (Astra) - parte 3 - P5', 'time_video': '07m26s', 'time_video_seconds': 446}
#
# 08 - Ajustes Finais do Tema (Astra) P5
# video_tree :: {'name': '08 - Ajustes Finais do Tema (Astra) P5', 'time_video': '16m37s', 'time_video_seconds': 997}
#
# 09 - Loja de Doces (OceanWp) - parte 1 - P1
# video_tree :: {'name': '09 - Loja de Doces (OceanWp) - parte 1 - P1', 'time_video': '04m56s', 'time_video_seconds': 296}
#
# 09 - Loja de Doces (OceanWp) - parte 2 - P1
# video_tree :: {'name': '09 - Loja de Doces (OceanWp) - parte 2 - P1', 'time_video': '13m36s', 'time_video_seconds': 816}
#
# 10 - Pagina Inicial Loja de doces (OceanWP) - parte 1 - P2
# video_tree :: {'name': '10 - Pagina Inicial Loja de doces (OceanWP) - parte 1 - P2', 'time_video': '05m47s', 'time_video_seconds': 347}
#
# 10 - Pagina Inicial Loja de doces (OceanWP) - parte 2 - P2
# video_tree :: {'name': '10 - Pagina Inicial Loja de doces (OceanWP) - parte 2 - P2', 'time_video': '09m36s', 'time_video_seconds': 576}
#
# 11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 1 - P3
# video_tree :: {'name': '11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 1 - P3', 'time_video': '08m45s', 'time_video_seconds': 525}
#
# 11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 2 - P3
# video_tree :: {'name': '11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 2 - P3', 'time_video': '04m49s', 'time_video_seconds': 289}
#
# 12 - Configurando Loja de Doces (OceanWP) - parte 1 - P4
# video_tree :: {'name': '12 - Configurando Loja de Doces (OceanWP) - parte 1 - P4', 'time_video': '05m58s', 'time_video_seconds': 358}
#
# 12 - Configurando Loja de Doces (OceanWP) - parte 2 - P4
# video_tree :: {'name': '12 - Configurando Loja de Doces (OceanWP) - parte 2 - P4', 'time_video': '01m40s', 'time_video_seconds': 100}
#
# 12 - Configurando Loja de Doces (OceanWP) - parte 3 - P4
# video_tree :: {'name': '12 - Configurando Loja de Doces (OceanWP) - parte 3 - P4', 'time_video': '02m16s', 'time_video_seconds': 136}
#
# 13 - Loja de Doces (OceanWP) - parte 1 - P5
# video_tree :: {'name': '13 - Loja de Doces (OceanWP) - parte 1 - P5', 'time_video': '02m27s', 'time_video_seconds': 147}
#
# 13 - Loja de Doces (OceanWP) - parte 2 - P5
# video_tree :: {'name': '13 - Loja de Doces (OceanWP) - parte 2 - P5', 'time_video': '02m25s', 'time_video_seconds': 145}
#
# 13 - Loja de Doces (OceanWP) - parte 3 - P5
# video_tree :: {'name': '13 - Loja de Doces (OceanWP) - parte 3 - P5', 'time_video': '02m25s', 'time_video_seconds': 145}
#
# 14 - Sistemas de Pagamentos - parte 1
# video_tree :: {'name': '14 - Sistemas de Pagamentos - parte 1', 'time_video': '06m43s', 'time_video_seconds': 403}
#
# 14 - Sistemas de Pagamentos - parte 2
# video_tree :: {'name': '14 - Sistemas de Pagamentos - parte 2', 'time_video': '03m25s', 'time_video_seconds': 205}
#
# 15 - Configurando SSL (IMPORTANTE) - parte 1
# video_tree :: {'name': '15 - Configurando SSL (IMPORTANTE) - parte 1', 'time_video': '06m27s', 'time_video_seconds': 387}
#
# 15 - Configurando SSL (IMPORTANTE) - parte 2
# video_tree :: {'name': '15 - Configurando SSL (IMPORTANTE) - parte 2', 'time_video': '05m06s', 'time_video_seconds': 306}
#
#
#  => module_tree ::
# {
#     "name": "09 - Fazendo Uma Loja Virtual",
#     "number": 9,
#     "finalize_name": "09 - Fazendo Uma Loja Virtual",
#     "time_module": "04h44m34s",
#     "time_module_seconds": 17074,
#     "number_of_videos": 34,
#     "files": [
#         {
#             "name": "01 - Passos Iniciais e Conceitos Basicos - parte 1",
#             "time_video": "01m09s",
#             "time_video_seconds": 69
#         },
#         {
#             "name": "01 - Passos Iniciais e Conceitos Basicos - parte 2",
#             "time_video": "03m18s",
#             "time_video_seconds": 198
#         },
#         {
#             "name": "02 - Planejando o Seu Ecommerce",
#             "time_video": "08m47s",
#             "time_video_seconds": 527
#         },
#         {
#             "name": "03 - Loja de Informatica (Astra) - parte 1 - P1",
#             "time_video": "01m33s",
#             "time_video_seconds": 93
#         },
#         {
#             "name": "03 - Loja de Informatica (Astra) - parte 2 - P1",
#             "time_video": "05m16s",
#             "time_video_seconds": 316
#         },
#         {
#             "name": "03 - Loja de Informatica (Astra) - parte 3 - P1",
#             "time_video": "02m54s",
#             "time_video_seconds": 174
#         },
#         {
#             "name": "04 - Loja de Informatica (Astra) - parte 1 - P2",
#             "time_video": "18m02s",
#             "time_video_seconds": 1082
#         },
#         {
#             "name": "04 - Loja de Informatica (Astra) - parte 2 - P2",
#             "time_video": "24m40s",
#             "time_video_seconds": 1480
#         },
#         {
#             "name": "05 - Paginas da Loja de Informatica (Astra) - parte 1 - P3",
#             "time_video": "20m58s",
#             "time_video_seconds": 1258
#         },
#         {
#             "name": "05 - Paginas da Loja de Informatica (Astra) - parte 2 - P3",
#             "time_video": "10m41s",
#             "time_video_seconds": 641
#         },
#         {
#             "name": "05 - Paginas da Loja de Informatica (Astra) - parte 3 - P3",
#             "time_video": "08m12s",
#             "time_video_seconds": 492
#         },
#         {
#             "name": "06 - Loja de Informatica (Astra) - parte 1 - P4",
#             "time_video": "15m00s",
#             "time_video_seconds": 900
#         },
#         {
#             "name": "06 - Loja de Informatica (Astra) - parte 2 - P4",
#             "time_video": "21m52s",
#             "time_video_seconds": 1312
#         },
#         {
#             "name": "06 - Loja de Informatica (Astra) - parte 3 - P4",
#             "time_video": "19m27s",
#             "time_video_seconds": 1167
#         },
#         {
#             "name": "07 - Loja de Informatica (Astra) - parte 1 - P5",
#             "time_video": "06m25s",
#             "time_video_seconds": 385
#         },
#         {
#             "name": "07 - Loja de Informatica (Astra) - parte 2 - P5",
#             "time_video": "05m56s",
#             "time_video_seconds": 356
#         },
#         {
#             "name": "07 - Loja de Informatica (Astra) - parte 3 - P5",
#             "time_video": "07m26s",
#             "time_video_seconds": 446
#         },
#         {
#             "name": "08 - Ajustes Finais do Tema (Astra) P5",
#             "time_video": "16m37s",
#             "time_video_seconds": 997
#         },
#         {
#             "name": "09 - Loja de Doces (OceanWp) - parte 1 - P1",
#             "time_video": "04m56s",
#             "time_video_seconds": 296
#         },
#         {
#             "name": "09 - Loja de Doces (OceanWp) - parte 2 - P1",
#             "time_video": "13m36s",
#             "time_video_seconds": 816
#         },
#         {
#             "name": "10 - Pagina Inicial Loja de doces (OceanWP) - parte 1 - P2",
#             "time_video": "05m47s",
#             "time_video_seconds": 347
#         },
#         {
#             "name": "10 - Pagina Inicial Loja de doces (OceanWP) - parte 2 - P2",
#             "time_video": "09m36s",
#             "time_video_seconds": 576
#         },
#         {
#             "name": "11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 1 - P3",
#             "time_video": "08m45s",
#             "time_video_seconds": 525
#         },
#         {
#             "name": "11 - Cadastrando Produtos Loja de Doces (OceanWP) - parte 2 - P3",
#             "time_video": "04m49s",
#             "time_video_seconds": 289
#         },
#         {
#             "name": "12 - Configurando Loja de Doces (OceanWP) - parte 1 - P4",
#             "time_video": "05m58s",
#             "time_video_seconds": 358
#         },
#         {
#             "name": "12 - Configurando Loja de Doces (OceanWP) - parte 2 - P4",
#             "time_video": "01m40s",
#             "time_video_seconds": 100
#         },
#         {
#             "name": "12 - Configurando Loja de Doces (OceanWP) - parte 3 - P4",
#             "time_video": "02m16s",
#             "time_video_seconds": 136
#         },
#         {
#             "name": "13 - Loja de Doces (OceanWP) - parte 1 - P5",
#             "time_video": "02m27s",
#             "time_video_seconds": 147
#         },
#         {
#             "name": "13 - Loja de Doces (OceanWP) - parte 2 - P5",
#             "time_video": "02m25s",
#             "time_video_seconds": 145
#         },
#         {
#             "name": "13 - Loja de Doces (OceanWP) - parte 3 - P5",
#             "time_video": "02m25s",
#             "time_video_seconds": 145
#         },
#         {
#             "name": "14 - Sistemas de Pagamentos - parte 1",
#             "time_video": "06m43s",
#             "time_video_seconds": 403
#         },
#         {
# ...
#             "name": "10 - Padronizando as P\u00e1ginas do Tema e Exportando as P\u00e1ginas",
#             "time_video": "03m26s",
#             "time_video_seconds": 206
#         },
#         {
#             "name": "11 - \u00daltimas Configura\u00e7\u00f5es - Preparando para a Entrega - parte 1",
#             "time_video": "02m22s",
#             "time_video_seconds": 142
#         },
#         {
#             "name": "11 - \u00daltimas Configura\u00e7\u00f5es - Preparando para a Entrega - parte 2",
#             "time_video": "04m59s",
#             "time_video_seconds": 299
#         },
#         {
#             "name": "11 - \u00daltimas Configura\u00e7\u00f5es - Preparando para a Entrega - parte 3",
#             "time_video": "04m33s",
#             "time_video_seconds": 273
#         },
#         {
#             "name": "12 - Conclus\u00e3o",
#             "time_video": "02m10s",
#             "time_video_seconds": 130
#         }
#     ]
# }
#
# ==================== 20 Análises de Sites de Alunos
#
# ----------- 20 - Análises de Sites de Alunos
# 02 - Site de Poker - Ivan
# video_tree :: {'name': '02 - Site de Poker - Ivan', 'time_video': '30m29s', 'time_video_seconds': 1829}
#
# 03 - Site Institucional - Evandro
# video_tree :: {'name': '03 - Site Institucional - Evandro', 'time_video': '56m39s', 'time_video_seconds': 3399}
#
# 04 - Site Institucional - Alto da Toca Baterias
# video_tree :: {'name': '04 - Site Institucional - Alto da Toca Baterias', 'time_video': '31m11s', 'time_video_seconds': 1871}
#
# 05 - Site de Vendas de um Evento - Noemy - parte 1
# video_tree :: {'name': '05 - Site de Vendas de um Evento - Noemy - parte 1', 'time_video': '30m01s', 'time_video_seconds': 1801}
#
# 05 - Site de Vendas de um Evento - Noemy - parte 2
# video_tree :: {'name': '05 - Site de Vendas de um Evento - Noemy - parte 2', 'time_video': '06m20s', 'time_video_seconds': 380}
#
# 06 - Página de Captura - Portfólio - Cristophe
# video_tree :: {'name': '06 - Página de Captura - Portfólio - Cristophe', 'time_video': '14m59s', 'time_video_seconds': 899}
#
# 07 - Site do Próprio Negócio - Renato Severo - cursoterapiafloral
# video_tree :: {'name': '07 - Site do Próprio Negócio - Renato Severo - cursoterapiafloral', 'time_video': '36m34s', 'time_video_seconds': 2194}
#
# 08 - Site de Cursos de Dança - Ricardo Abelhas
# video_tree :: {'name': '08 - Site de Cursos de Dança - Ricardo Abelhas', 'time_video': '31m25s', 'time_video_seconds': 1885}
#
#
#  => module_tree ::
# {
#     "name": "20 - An\u00e1lises de Sites de Alunos",
#     "number": 20,
#     "finalize_name": "20 - An\u00e1lises de Sites de Alunos",
#     "time_module": "03h57m38s",
#     "time_module_seconds": 14258,
#     "number_of_videos": 8,
#     "files": [
#         {
#             "name": "02 - Site de Poker - Ivan",
#             "time_video": "30m29s",
#             "time_video_seconds": 1829
#         },
#         {
#             "name": "03 - Site Institucional - Evandro",
#             "time_video": "56m39s",
#             "time_video_seconds": 3399
#         },
#         {
#             "name": "04 - Site Institucional - Alto da Toca Baterias",
#             "time_video": "31m11s",
#             "time_video_seconds": 1871
#         },
#         {
#             "name": "05 - Site de Vendas de um Evento - Noemy - parte 1",
#             "time_video": "30m01s",
#             "time_video_seconds": 1801
#         },
#         {
#             "name": "05 - Site de Vendas de um Evento - Noemy - parte 2",
#             "time_video": "06m20s",
#             "time_video_seconds": 380
#         },
#         {
#             "name": "06 - P\u00e1gina de Captura - Portf\u00f3lio - Cristophe",
#             "time_video": "14m59s",
#             "time_video_seconds": 899
#         },
#         {
#             "name": "07 - Site do Pr\u00f3prio Neg\u00f3cio - Renato Severo - cursoterapiafloral",
#             "time_video": "36m34s",
#             "time_video_seconds": 2194
#         },
#         {
#             "name": "08 - Site de Cursos de Dan\u00e7a - Ricardo Abelhas",
#             "time_video": "31m25s",
#             "time_video_seconds": 1885
#         }
#     ]
# }
#
# ==================== 21 MENTORIAS EM GRUPO
#
# ----------- 21 - MENTORIAS EM GRUPO
# 01 - MENTORIA EM GRUPO
# video_tree :: {'name': '01 - MENTORIA EM GRUPO', 'time_video': '02h35m09s', 'time_video_seconds': 9309}
#
# 02 - MENTORIA EM GRUPO
# video_tree :: {'name': '02 - MENTORIA EM GRUPO', 'time_video': '01h49m02s', 'time_video_seconds': 6542}
#
# 03 - MENTORIA EM GRUPO
# video_tree :: {'name': '03 - MENTORIA EM GRUPO', 'time_video': '01h20m38s', 'time_video_seconds': 4838}
#
# 04 - MENTORIA EM GRUPO
# video_tree :: {'name': '04 - MENTORIA EM GRUPO', 'time_video': '02h12m38s', 'time_video_seconds': 7958}
#
# 05 - MENTORIA EM GRUPO
# video_tree :: {'name': '05 - MENTORIA EM GRUPO', 'time_video': '02h01m46s', 'time_video_seconds': 7306}
#
#
#  => module_tree ::
# {
#     "name": "21 - MENTORIAS EM GRUPO",
#     "number": 21,
#     "finalize_name": "21 - MENTORIAS EM GRUPO",
#     "time_module": "09h59m13s",
#     "time_module_seconds": 35953,
#     "number_of_videos": 5,
#     "files": [
#         {
#             "name": "01 - MENTORIA EM GRUPO",
#             "time_video": "02h35m09s",
#             "time_video_seconds": 9309
#         },
#         {
#             "name": "02 - MENTORIA EM GRUPO",
#             "time_video": "01h49m02s",
#             "time_video_seconds": 6542
#         },
#         {
#             "name": "03 - MENTORIA EM GRUPO",
#             "time_video": "01h20m38s",
#             "time_video_seconds": 4838
#         },
#         {
#             "name": "04 - MENTORIA EM GRUPO",
#             "time_video": "02h12m38s",
#             "time_video_seconds": 7958
#         },
#         {
#             "name": "05 - MENTORIA EM GRUPO",
#             "time_video": "02h01m46s",
#             "time_video_seconds": 7306
#         }
#     ]
# }
#
# ==================== 22 MOBILE FIRST
#
# ----------- 22 - MOBILE FIRST
# 01 - Pense Mobile First! (AULÃO DE SEXTA)
# video_tree :: {'name': '01 - Pense Mobile First! (AULÃO DE SEXTA)', 'time_video': '02h11m07s', 'time_video_seconds': 7867}
#
# 02 - Passo a Passo - Introdução
# video_tree :: {'name': '02 - Passo a Passo - Introdução', 'time_video': '03m49s', 'time_video_seconds': 229}
#
# 03 - Página Inicial - parte 1
# video_tree :: {'name': '03 - Página Inicial - parte 1', 'time_video': '08m11s', 'time_video_seconds': 491}
#
# 03 - Página Inicial - parte 2
# video_tree :: {'name': '03 - Página Inicial - parte 2', 'time_video': '07m56s', 'time_video_seconds': 476}
#
# 03 - Página Inicial - parte 3
# video_tree :: {'name': '03 - Página Inicial - parte 3', 'time_video': '09m56s', 'time_video_seconds': 596}
#
# 04 - Carrossel
# video_tree :: {'name': '04 - Carrossel', 'time_video': '15m36s', 'time_video_seconds': 936}
#
# 05 - Footer
# video_tree :: {'name': '05 - Footer', 'time_video': '07m56s', 'time_video_seconds': 476}
#
# 06 - PopUps - parte 1
# video_tree :: {'name': '06 - PopUps - parte 1', 'time_video': '06m02s', 'time_video_seconds': 362}
#
# 06 - PopUps - parte 2
# video_tree :: {'name': '06 - PopUps - parte 2', 'time_video': '05m22s', 'time_video_seconds': 322}
#
#
#  => module_tree ::
# {
#     "name": "22 - MOBILE FIRST",
#     "number": 22,
#     "finalize_name": "22 - MOBILE FIRST",
#     "time_module": "03h15m55s",
#     "time_module_seconds": 11755,
#     "number_of_videos": 9,
#     "files": [
#         {
#             "name": "01 - Pense Mobile First! (AUL\u00c3O DE SEXTA)",
#             "time_video": "02h11m07s",
#             "time_video_seconds": 7867
#         },
#         {
#             "name": "02 - Passo a Passo - Introdu\u00e7\u00e3o",
#             "time_video": "03m49s",
#             "time_video_seconds": 229
#         },
#         {
#             "name": "03 - P\u00e1gina Inicial - parte 1",
#             "time_video": "08m11s",
#             "time_video_seconds": 491
#         },
#         {
#             "name": "03 - P\u00e1gina Inicial - parte 2",
#             "time_video": "07m56s",
#             "time_video_seconds": 476
#         },
#         {
#             "name": "03 - P\u00e1gina Inicial - parte 3",
#             "time_video": "09m56s",
#             "time_video_seconds": 596
#         },
#         {
#             "name": "04 - Carrossel",
#             "time_video": "15m36s",
#             "time_video_seconds": 936
#         },
#         {
#             "name": "05 - Footer",
#             "time_video": "07m56s",
#             "time_video_seconds": 476
#         },
#         {
#             "name": "06 - PopUps - parte 1",
#             "time_video": "06m02s",
#             "time_video_seconds": 362
#         },
#         {
#             "name": "06 - PopUps - parte 2",
#             "time_video": "05m22s",
#             "time_video_seconds": 322
#         }
#     ]
# }
#
# ==================== 23 Trabalhando de Forma Remota
#
# ----------- 23 - Trabalhando de Forma Remota
# 01 - Introdução
# video_tree :: {'name': '01 - Introdução', 'time_video': '02m22s', 'time_video_seconds': 142}
#
# 02 - Zoom
# video_tree :: {'name': '02 - Zoom', 'time_video': '09m13s', 'time_video_seconds': 553}
#
# 03 - Google Drive
# video_tree :: {'name': '03 - Google Drive', 'time_video': '09m18s', 'time_video_seconds': 558}
#
# 04 - Trello
# video_tree :: {'name': '04 - Trello', 'time_video': '19m42s', 'time_video_seconds': 1182}
#
# 05 - YouCanBookMe - parte 1
# video_tree :: {'name': '05 - YouCanBookMe - parte 1', 'time_video': '23m10s', 'time_video_seconds': 1390}
#
# 05 - YouCanBookMe - parte 2
# video_tree :: {'name': '05 - YouCanBookMe - parte 2', 'time_video': '05m25s', 'time_video_seconds': 325}
#
# 06 - Discord
# video_tree :: {'name': '06 - Discord', 'time_video': '04m50s', 'time_video_seconds': 290}
#
# 07 - Slack
# video_tree :: {'name': '07 - Slack', 'time_video': '06m25s', 'time_video_seconds': 385}
#
#
#  => module_tree ::
# {
#     "name": "23 - Trabalhando de Forma Remota",
#     "number": 23,
#     "finalize_name": "23 - Trabalhando de Forma Remota",
#     "time_module": "01h20m25s",
#     "time_module_seconds": 4825,
#     "number_of_videos": 8,
#     "files": [
#         {
#             "name": "01 - Introdu\u00e7\u00e3o",
#             "time_video": "02m22s",
#             "time_video_seconds": 142
#         },
#         {
#             "name": "02 - Zoom",
#             "time_video": "09m13s",
#             "time_video_seconds": 553
#         },
#         {
#             "name": "03 - Google Drive",
#             "time_video": "09m18s",
#             "time_video_seconds": 558
#         },
#         {
#             "name": "04 - Trello",
#             "time_video": "19m42s",
#             "time_video_seconds": 1182
#         },
#         {
#             "name": "05 - YouCanBookMe - parte 1",
#             "time_video": "23m10s",
#             "time_video_seconds": 1390
#         },
#         {
#             "name": "05 - YouCanBookMe - parte 2",
#             "time_video": "05m25s",
#             "time_video_seconds": 325
#         },
#         {
#             "name": "06 - Discord",
#             "time_video": "04m50s",
#             "time_video_seconds": 290
#         },
#         {
#             "name": "07 - Slack",
#             "time_video": "06m25s",
#             "time_video_seconds": 385
#         }
#     ]
# }
#
# ==================== 24 Site Anitta
#
# ----------- 24 - Site Anitta
# 01 - Construção do Layout
# video_tree :: {'name': '01 - Construção do Layout', 'time_video': '32m26s', 'time_video_seconds': 1946}
#
# 02 - Mouse Track e 3D Tilt
# video_tree :: {'name': '02 - Mouse Track e 3D Tilt', 'time_video': '11m58s', 'time_video_seconds': 718}
#
# 03 - Criando um PopUp Acionado por Botão
# video_tree :: {'name': '03 - Criando um PopUp Acionado por Botão', 'time_video': '14m57s', 'time_video_seconds': 897}
#
#
#  => module_tree ::
# {
#     "name": "24 - Site Anitta - (Efeitos de Movimento e PopUp)",
#     "number": 24,
#     "finalize_name": "24 - Site Anitta",
#     "time_module": "59m21s",
#     "time_module_seconds": 3561,
#     "number_of_videos": 3,
#     "files": [
#         {
#             "name": "01 - Constru\u00e7\u00e3o do Layout",
#             "time_video": "32m26s",
#             "time_video_seconds": 1946
#         },
#         {
#             "name": "02 - Mouse Track e 3D Tilt",
#             "time_video": "11m58s",
#             "time_video_seconds": 718
#         },
#         {
#             "name": "03 - Criando um PopUp Acionado por Bot\u00e3o",
#             "time_video": "14m57s",
#             "time_video_seconds": 897
#         }
#     ]
# }
#
# ==================== 25 Teoria das Cores
#
# ----------- 25 - Teoria das Cores
# 08 - Atualização - Salvando as Cores Padrões no Elementor
# video_tree :: {'name': '08 - Atualização - Salvando as Cores Padrões no Elementor', 'time_video': '03m04s', 'time_video_seconds': 184}
#
#
#  => module_tree ::
# {
#     "name": "25 - Teoria das Cores",
#     "number": 25,
#     "finalize_name": "25 - Teoria das Cores",
#     "time_module": "03m04s",
#     "time_module_seconds": 184,
#     "number_of_videos": 1,
#     "files": [
#         {
#             "name": "08 - Atualiza\u00e7\u00e3o - Salvando as Cores Padr\u00f5es no Elementor",
#             "time_video": "03m04s",
#             "time_video_seconds": 184
#         }
#     ]
# }
#
# ==================== 26 Como Criar um Logotipo Simples
#
# ----------- 26 - Como Criar um Logotipo Simples
# 01 - Canva
# video_tree :: {'name': '01 - Canva', 'time_video': '04m00s', 'time_video_seconds': 240}
#
# 02 - Logotipo - Modelo 1
# video_tree :: {'name': '02 - Logotipo - Modelo 1', 'time_video': '06m01s', 'time_video_seconds': 361}
#
# 03 - Logotipo - Modelo 2
# video_tree :: {'name': '03 - Logotipo - Modelo 2', 'time_video': '09m58s', 'time_video_seconds': 598}
#
# 04 - Tirando o Fundo do Logotipo e Algumas Dicas
# video_tree :: {'name': '04 - Tirando o Fundo do Logotipo e Algumas Dicas', 'time_video': '04m14s', 'time_video_seconds': 254}
#
# 05 - Bônu - Vintepila e Workana
# video_tree :: {'name': '05 - Bônu - Vintepila e Workana', 'time_video': '01m04s', 'time_video_seconds': 64}
#
#
#  => module_tree ::
# {
#     "name": "26 - Como Criar um Logotipo Simples",
#     "number": 26,
#     "finalize_name": "26 - Como Criar um Logotipo Simples",
#     "time_module": "25m17s",
#     "time_module_seconds": 1517,
#     "number_of_videos": 5,
#     "files": [
#         {
#             "name": "01 - Canva",
#             "time_video": "04m00s",
#             "time_video_seconds": 240
#         },
#         {
#             "name": "02 - Logotipo - Modelo 1",
#             "time_video": "06m01s",
#             "time_video_seconds": 361
#         },
#         {
#             "name": "03 - Logotipo - Modelo 2",
#             "time_video": "09m58s",
#             "time_video_seconds": 598
#         },
#         {
#             "name": "04 - Tirando o Fundo do Logotipo e Algumas Dicas",
#             "time_video": "04m14s",
#             "time_video_seconds": 254
#         },
#         {
#             "name": "05 - B\u00f4nu - Vintepila e Workana",
#             "time_video": "01m04s",
#             "time_video_seconds": 64
#         }
#     ]
# }
#
# ==================== 27 Maratona Lucrando com Sites
#
# ----------- 27 - Maratona Lucrando com Sites
# 01 - Por que um site vale BEM mais que R$2.500
# video_tree :: {'name': '01 - Por que um site vale BEM mais que R$2.500', 'time_video': '50m06s', 'time_video_seconds': 3006}
#
# 02 - Ferramentas Necessárias para Criar um Site Profissional
# video_tree :: {'name': '02 - Ferramentas Necessárias para Criar um Site Profissional', 'time_video': '33m13s', 'time_video_seconds': 1993}
#
# 03 - Como fechar seus projetos com Clientes!
# video_tree :: {'name': '03 - Como fechar seus projetos com Clientes!', 'time_video': '49m03s', 'time_video_seconds': 2943}
#
#
#  => module_tree ::
# {
#     "name": "27 - Maratona Lucrando com Sites",
#     "number": 27,
#     "finalize_name": "27 - Maratona Lucrando com Sites",
#     "time_module": "02h12m22s",
#     "time_module_seconds": 7942,
#     "number_of_videos": 3,
#     "files": [
#         {
#             "name": "01 - Por que um site vale BEM mais que R$2.500",
#             "time_video": "50m06s",
#             "time_video_seconds": 3006
#         },
#         {
#             "name": "02 - Ferramentas Necess\u00e1rias para Criar um Site Profissional",
#             "time_video": "33m13s",
#             "time_video_seconds": 1993
#         },
#         {
#             "name": "03 - Como fechar seus projetos com Clientes!",
#             "time_video": "49m03s",
#             "time_video_seconds": 2943
#         }
#     ]
# }

# %%
# itera para pegar tempo total
for el in course_tree['modules']:
    course_tree['time_course_seconds'] += el['time_module_seconds']
    course_tree['number_of_modules'] += 1

h, m, s = convert(course_tree['time_course_seconds'])
course_tree['time_course'] = get_convert(h, m, s)

# Salvar em JSON
with open('data.json', 'w') as fp:
    json.dump(course_tree, fp)

# %% [markdown]
# ## Create `README-GLOBAL.md`

# %%
with open("README-GLOBAL.md",'w', encoding = 'utf-8') as f:
    f.write("# {}\n\n".format(course_tree['name_course']))
    f.write("Tempo: {} || Quantidade de Módulos {}\n\n".format(
        course_tree['time_course'], course_tree['number_of_modules'],))
    f.write("## File Tree\n\n")
    for el in course_tree['modules']:
        f.write("├─── {} ({})\n".format(el['finalize_name'], el['time_module']))
        for il in el['files']:
            f.write("│       {} ({})\n".format(il['name'], il['time_video']))
        f.write('│\n')

# %% [markdown]
# ## Create individual `README.md` to each module

# %%
# Escrevendo N Modulos
for el in course_tree['modules']:
    # str(el['number']).zfill(2) + '-'
    file_module_name = el['finalize_name'] + '.md'
    with open(file_module_name, 'w', encoding = 'utf-8') as f:
        f.write("# {}\n\n".format(el['finalize_name']))
        f.write("Tempo: {} || Quantidade de Vídeos {}\n\n".format(
        el['time_module'], el['number_of_videos'],))
        for il in el['files']:
            f.write("## {} ({})\n\n\n\n".format(il['name'], il['time_video']))
